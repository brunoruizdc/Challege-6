# %% [markdown]
# <img src="https://i.imgur.com/6U6q5jQ.png"/>
#
# _____

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/SocialAnalytics-StrategicIntelligence/introSocialSim/blob/main/IntroSocialSim.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# # Introduction to Social Simulation
#
# Statistical analysis benefits primarily the study of variables/ factors distributions. We could complement that approach if we focus on the actors that produce the variables.
#
# However, representing the actor is not an easy task:
#
# * A social outcome is a **complex** aggregate of individual actors. In general we call social outcomes **emergent** results of individual decisions.
#
# * Individual decisions have been assumed to be rational, which over simplyfies models of actors. As a matter of fact, decision making is a field under study.
#
# * Information processing of agents is biased by "culture" (beliefs, experience) and institutions (rules, habits). And many paradigms can co-exist in a particular group. Change is possible, but social structure and culture limits it.
#
# * Actors actions and decisions occur within a network of agents. An actor can be part of several networks.
#
#
# The field related to this study is **Computational Social Science**. The particular methodology is **agent-based modelling**.

# %% [markdown]
# # A simple game as an example
#
# According to WIKIPEDIA, the game Rock, Paper, Scissors is a simultaneous, zero-sum game, with three possible outcomes: a draw, a win, or a loss:
#
# * A player who decides to play **ROCK** will beat another player who chooses **SCISSORS** ("rock crushes scissors" or "breaks scissors")
# * A player who decides to play **ROCK**  will lose to one who has played **PAPER** ("paper covers rock").
# * A player who decides to play **PAPER** will lose to a play of **SCISSORS** ("scissors cuts paper").
# * If both players choose the same shape, the game is tied.
#
# Let´s represent the game:
#
# ## Strategies
#
# Strategies are the options available:

# %%
strategies=['Rock','Paper','Scissors']

# %% [markdown]
# ## Rules
#
# The rules tell you that according to a strategy followed, players get a pay-off:

# %%
payoff={('Rock','Paper'):(0,1),
        ('Paper','Rock'):(1,0),
        ('Rock','Scissors'):(1,0),
        ('Scissors','Rock'):(0,1),
        ('Paper','Scissors'):(0,1),
        ('Scissors','Paper'):(1,0),
        ('Rock','Rock'):(0,0),
        ('Paper','Paper'):(0,0),
        ('Scissors','Scissors'):(0,0)}

# %% [markdown]
# ## Creating and setting up agents:
#
# Players have a name, but have no score, and no strategy yet.

# %%
Players=[{'name':'John','score':0,'strategy':None},
         {'name':'Mary','score':0,'strategy':None}]

# %% [markdown]
# ## Decision making process
#
# This is the process to choose an strategy:

# %%
from random import choice

#simplest strategy: choose randomly
choice(strategies);

# %% [markdown]
# ## The moment of truth

# %% [markdown]
# * ### agent decide strategy

# %%
Players[0]['strategy']=choice(strategies)
Players[1]['strategy']=choice(strategies)

# %% [markdown]
# * ### decisions made

# %%
Players[0]['strategy'],Players[1]['strategy']
# Out:
# ('Scissors', 'Rock')

# %%
# social result of individual decision
result = payoff[Players[0]['strategy'],Players[1]['strategy']]
result
# Out:
# (0, 1)

# %% [markdown]
# * ### agent benefits/suffers from decision made

# %%
# update agents situation
Players[0]['score']+=result[0]
Players[1]['score']+=result[1]

# %%
# current agent situation
Players
# Out:
# [{'name': 'John', 'score': 0, 'strategy': 'Scissors'},
#  {'name': 'Mary', 'score': 1, 'strategy': 'Rock'}]

# %% [markdown]
# * ### social outcome

# %%
import pandas as pd

socialResults=pd.DataFrame((Players[0], Players[1]))
socialResults
# Out:
#    name  score  strategy
# 0  John      0  Scissors
# 1  Mary      1      Rock

# %%
winnerScore=socialResults.score.max()

#social outcome
socialResults[socialResults.score==winnerScore]
# Out:
#    name  score strategy
# 1  Mary      1     Rock

# %% [markdown]
# # More players

# %%
# names of players
names=['Jim','Jane','Peter','Zoe']

# %%
# setting up players
society=[{'name':n,'score':0,'strategy':None} for n in names]

# %%
# each player a dict:
society
# Out:
# [{'name': 'Jim', 'score': 0, 'strategy': None},
#  {'name': 'Jane', 'score': 0, 'strategy': None},
#  {'name': 'Peter', 'score': 0, 'strategy': None},
#  {'name': 'Zoe', 'score': 0, 'strategy': None}]

# %%
import itertools

# pair is a tuple of dicts
for pair in itertools.combinations(society,2):
    print(pair)
# Out:
# ({'name': 'Jim', 'score': 0, 'strategy': None}, {'name': 'Jane', 'score': 0, 'strategy': None})
# ({'name': 'Jim', 'score': 0, 'strategy': None}, {'name': 'Peter', 'score': 0, 'strategy': None})
# ({'name': 'Jim', 'score': 0, 'strategy': None}, {'name': 'Zoe', 'score': 0, 'strategy': None})
# ({'name': 'Jane', 'score': 0, 'strategy': None}, {'name': 'Peter', 'score': 0, 'strategy': None})
# ({'name': 'Jane', 'score': 0, 'strategy': None}, {'name': 'Zoe', 'score': 0, 'strategy': None})
# ({'name': 'Peter', 'score': 0, 'strategy': None}, {'name': 'Zoe', 'score': 0, 'strategy': None})

# %%
import itertools

# each dict
for player1,player2 in itertools.combinations(society,2):
    print(player1,player2)
# Out:
# {'name': 'Jim', 'score': 0, 'strategy': None} {'name': 'Jane', 'score': 0, 'strategy': None}
# {'name': 'Jim', 'score': 0, 'strategy': None} {'name': 'Peter', 'score': 0, 'strategy': None}
# {'name': 'Jim', 'score': 0, 'strategy': None} {'name': 'Zoe', 'score': 0, 'strategy': None}
# {'name': 'Jane', 'score': 0, 'strategy': None} {'name': 'Peter', 'score': 0, 'strategy': None}
# {'name': 'Jane', 'score': 0, 'strategy': None} {'name': 'Zoe', 'score': 0, 'strategy': None}
# {'name': 'Peter', 'score': 0, 'strategy': None} {'name': 'Zoe', 'score': 0, 'strategy': None}

# %%
for aRound in range(100):
    print(f"--- Round {aRound + 1} ---")

    for player1, player2 in itertools.combinations(society, 2):
        # Each player chooses a random strategy
        player1['strategy'] = choice(strategies)
        player2['strategy'] = choice(strategies)

        # Result from strategy chosen
        result = payoff[player1['strategy'], player2['strategy']]

        # Update scores
        # player1[score'] += result[0]
        player2['score'] += result[1]

        # Print match result
        winner = "Tie"
        if result[0] > result[1]:
            winner = player1['name']
        elif result[1] > result[0]:
            winner = player2['name']
        
        print(f"{player1['name']} ({player1['strategy']}) vs {player2['name']} ({player2['strategy']}) => Winner: {winner}")

    # Print the scores
    print("\nCurrent Scores:")
    for player in society:
        print(f"{player['name']}: {player['score']} points")
    print("\n")
# Out:
# --- Round 1 ---
# Jim (Rock) vs Jane (Rock) => Winner: Tie
# Jim (Rock) vs Peter (Scissors) => Winner: Jim
# Jim (Rock) vs Zoe (Scissors) => Winner: Jim
# Jane (Scissors) vs Peter (Rock) => Winner: Peter
# Jane (Paper) vs Zoe (Scissors) => Winner: Zoe
# Peter (Paper) vs Zoe (Scissors) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 296 points
# Peter: 298 points
# Zoe: 331 points
#
#
# --- Round 2 ---
# Jim (Rock) vs Jane (Rock) => Winner: Tie
# Jim (Scissors) vs Peter (Paper) => Winner: Jim
# Jim (Scissors) vs Zoe (Paper) => Winner: Jim
# Jane (Paper) vs Peter (Rock) => Winner: Jane
# Jane (Scissors) vs Zoe (Paper) => Winner: Jane
# Peter (Rock) vs Zoe (Scissors) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 296 points
# Peter: 298 points
# Zoe: 331 points
#
#
# --- Round 3 ---
# Jim (Paper) vs Jane (Scissors) => Winner: Jane
# Jim (Scissors) vs Peter (Scissors) => Winner: Tie
# Jim (Rock) vs Zoe (Scissors) => Winner: Jim
# Jane (Scissors) vs Peter (Scissors) => Winner: Tie
# Jane (Scissors) vs Zoe (Rock) => Winner: Zoe
# Peter (Paper) vs Zoe (Rock) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 297 points
# Peter: 298 points
# Zoe: 332 points
#
#
# --- Round 4 ---
# Jim (Paper) vs Jane (Rock) => Winner: Jim
# Jim (Scissors) vs Peter (Rock) => Winner: Peter
# Jim (Rock) vs Zoe (Rock) => Winner: Tie
# Jane (Rock) vs Peter (Rock) => Winner: Tie
# Jane (Rock) vs Zoe (Rock) => Winner: Tie
# Peter (Paper) vs Zoe (Rock) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 297 points
# Peter: 299 points
# Zoe: 332 points
#
#
# --- Round 5 ---
# Jim (Paper) vs Jane (Paper) => Winner: Tie
# Jim (Rock) vs Peter (Paper) => Winner: Peter
# Jim (Paper) vs Zoe (Paper) => Winner: Tie
# Jane (Rock) vs Peter (Paper) => Winner: Peter
# Jane (Rock) vs Zoe (Rock) => Winner: Tie
# Peter (Rock) vs Zoe (Scissors) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 297 points
# Peter: 301 points
# Zoe: 332 points
#
#
# --- Round 6 ---
# Jim (Rock) vs Jane (Paper) => Winner: Jane
# Jim (Scissors) vs Peter (Paper) => Winner: Jim
# Jim (Scissors) vs Zoe (Rock) => Winner: Zoe
# Jane (Scissors) vs Peter (Paper) => Winner: Jane
# Jane (Scissors) vs Zoe (Paper) => Winner: Jane
# Peter (Scissors) vs Zoe (Paper) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 298 points
# Peter: 301 points
# Zoe: 333 points
#
#
# --- Round 7 ---
# Jim (Rock) vs Jane (Scissors) => Winner: Jim
# Jim (Rock) vs Peter (Rock) => Winner: Tie
# Jim (Scissors) vs Zoe (Paper) => Winner: Jim
# Jane (Rock) vs Peter (Rock) => Winner: Tie
# Jane (Paper) vs Zoe (Paper) => Winner: Tie
# Peter (Rock) vs Zoe (Rock) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 298 points
# Peter: 301 points
# Zoe: 333 points
#
#
# --- Round 8 ---
# Jim (Scissors) vs Jane (Scissors) => Winner: Tie
# Jim (Paper) vs Peter (Paper) => Winner: Tie
# Jim (Paper) vs Zoe (Scissors) => Winner: Zoe
# Jane (Scissors) vs Peter (Paper) => Winner: Jane
# Jane (Paper) vs Zoe (Rock) => Winner: Jane
# Peter (Scissors) vs Zoe (Rock) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 298 points
# Peter: 301 points
# Zoe: 335 points
#
#
# --- Round 9 ---
# Jim (Rock) vs Jane (Rock) => Winner: Tie
# Jim (Scissors) vs Peter (Rock) => Winner: Peter
# Jim (Rock) vs Zoe (Scissors) => Winner: Jim
# Jane (Scissors) vs Peter (Paper) => Winner: Jane
# Jane (Scissors) vs Zoe (Rock) => Winner: Zoe
# Peter (Scissors) vs Zoe (Paper) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 298 points
# Peter: 302 points
# Zoe: 336 points
#
#
# --- Round 10 ---
# Jim (Paper) vs Jane (Rock) => Winner: Jim
# Jim (Rock) vs Peter (Scissors) => Winner: Jim
# Jim (Scissors) vs Zoe (Paper) => Winner: Jim
# Jane (Scissors) vs Peter (Paper) => Winner: Jane
# Jane (Paper) vs Zoe (Scissors) => Winner: Zoe
# Peter (Rock) vs Zoe (Scissors) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 298 points
# Peter: 302 points
# Zoe: 337 points
#
#
# --- Round 11 ---
# Jim (Paper) vs Jane (Scissors) => Winner: Jane
# Jim (Rock) vs Peter (Paper) => Winner: Peter
# Jim (Rock) vs Zoe (Paper) => Winner: Zoe
# Jane (Rock) vs Peter (Rock) => Winner: Tie
# Jane (Paper) vs Zoe (Rock) => Winner: Jane
# Peter (Paper) vs Zoe (Paper) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 299 points
# Peter: 303 points
# Zoe: 338 points
#
#
# --- Round 12 ---
# Jim (Paper) vs Jane (Paper) => Winner: Tie
# Jim (Scissors) vs Peter (Scissors) => Winner: Tie
# Jim (Rock) vs Zoe (Rock) => Winner: Tie
# Jane (Scissors) vs Peter (Rock) => Winner: Peter
# Jane (Rock) vs Zoe (Paper) => Winner: Zoe
# Peter (Rock) vs Zoe (Scissors) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 299 points
# Peter: 304 points
# Zoe: 339 points
#
#
# --- Round 13 ---
# Jim (Paper) vs Jane (Paper) => Winner: Tie
# Jim (Scissors) vs Peter (Paper) => Winner: Jim
# Jim (Scissors) vs Zoe (Rock) => Winner: Zoe
# Jane (Rock) vs Peter (Rock) => Winner: Tie
# Jane (Scissors) vs Zoe (Rock) => Winner: Zoe
# Peter (Scissors) vs Zoe (Rock) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 299 points
# Peter: 304 points
# Zoe: 342 points
#
#
# --- Round 14 ---
# Jim (Paper) vs Jane (Rock) => Winner: Jim
# Jim (Rock) vs Peter (Scissors) => Winner: Jim
# Jim (Paper) vs Zoe (Rock) => Winner: Jim
# Jane (Scissors) vs Peter (Rock) => Winner: Peter
# Jane (Rock) vs Zoe (Scissors) => Winner: Jane
# Peter (Rock) vs Zoe (Paper) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 299 points
# Peter: 305 points
# Zoe: 343 points
#
#
# --- Round 15 ---
# Jim (Scissors) vs Jane (Scissors) => Winner: Tie
# Jim (Scissors) vs Peter (Scissors) => Winner: Tie
# Jim (Scissors) vs Zoe (Rock) => Winner: Zoe
# Jane (Rock) vs Peter (Rock) => Winner: Tie
# Jane (Rock) vs Zoe (Scissors) => Winner: Jane
# Peter (Paper) vs Zoe (Paper) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 299 points
# Peter: 305 points
# Zoe: 344 points
#
#
# --- Round 16 ---
# Jim (Paper) vs Jane (Rock) => Winner: Jim
# Jim (Paper) vs Peter (Paper) => Winner: Tie
# Jim (Scissors) vs Zoe (Paper) => Winner: Jim
# Jane (Rock) vs Peter (Rock) => Winner: Tie
# Jane (Paper) vs Zoe (Rock) => Winner: Jane
# Peter (Rock) vs Zoe (Scissors) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 299 points
# Peter: 305 points
# Zoe: 344 points
#
#
# --- Round 17 ---
# Jim (Rock) vs Jane (Scissors) => Winner: Jim
# Jim (Scissors) vs Peter (Scissors) => Winner: Tie
# Jim (Paper) vs Zoe (Rock) => Winner: Jim
# Jane (Rock) vs Peter (Rock) => Winner: Tie
# Jane (Rock) vs Zoe (Scissors) => Winner: Jane
# Peter (Scissors) vs Zoe (Paper) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 299 points
# Peter: 305 points
# Zoe: 344 points
#
#
# --- Round 18 ---
# Jim (Scissors) vs Jane (Paper) => Winner: Jim
# Jim (Rock) vs Peter (Scissors) => Winner: Jim
# Jim (Rock) vs Zoe (Rock) => Winner: Tie
# Jane (Paper) vs Peter (Rock) => Winner: Jane
# Jane (Scissors) vs Zoe (Rock) => Winner: Zoe
# Peter (Paper) vs Zoe (Rock) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 299 points
# Peter: 305 points
# Zoe: 345 points
#
#
# --- Round 19 ---
# Jim (Paper) vs Jane (Paper) => Winner: Tie
# Jim (Paper) vs Peter (Rock) => Winner: Jim
# Jim (Rock) vs Zoe (Paper) => Winner: Zoe
# Jane (Paper) vs Peter (Scissors) => Winner: Peter
# Jane (Scissors) vs Zoe (Rock) => Winner: Zoe
# Peter (Scissors) vs Zoe (Paper) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 299 points
# Peter: 306 points
# Zoe: 347 points
#
#
# --- Round 20 ---
# Jim (Scissors) vs Jane (Paper) => Winner: Jim
# Jim (Rock) vs Peter (Scissors) => Winner: Jim
# Jim (Paper) vs Zoe (Scissors) => Winner: Zoe
# Jane (Rock) vs Peter (Rock) => Winner: Tie
# Jane (Paper) vs Zoe (Rock) => Winner: Jane
# Peter (Scissors) vs Zoe (Rock) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 299 points
# Peter: 306 points
# Zoe: 349 points
#
#
# --- Round 21 ---
# Jim (Paper) vs Jane (Paper) => Winner: Tie
# Jim (Rock) vs Peter (Scissors) => Winner: Jim
# Jim (Scissors) vs Zoe (Rock) => Winner: Zoe
# Jane (Paper) vs Peter (Scissors) => Winner: Peter
# Jane (Rock) vs Zoe (Rock) => Winner: Tie
# Peter (Rock) vs Zoe (Rock) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 299 points
# Peter: 307 points
# Zoe: 350 points
#
#
# --- Round 22 ---
# Jim (Rock) vs Jane (Rock) => Winner: Tie
# Jim (Scissors) vs Peter (Rock) => Winner: Peter
# Jim (Paper) vs Zoe (Scissors) => Winner: Zoe
# Jane (Rock) vs Peter (Rock) => Winner: Tie
# Jane (Rock) vs Zoe (Rock) => Winner: Tie
# Peter (Rock) vs Zoe (Rock) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 299 points
# Peter: 308 points
# Zoe: 351 points
#
#
# --- Round 23 ---
# Jim (Scissors) vs Jane (Rock) => Winner: Jane
# Jim (Scissors) vs Peter (Scissors) => Winner: Tie
# Jim (Scissors) vs Zoe (Rock) => Winner: Zoe
# Jane (Paper) vs Peter (Rock) => Winner: Jane
# Jane (Paper) vs Zoe (Rock) => Winner: Jane
# Peter (Scissors) vs Zoe (Scissors) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 300 points
# Peter: 308 points
# Zoe: 352 points
#
#
# --- Round 24 ---
# Jim (Paper) vs Jane (Rock) => Winner: Jim
# Jim (Scissors) vs Peter (Rock) => Winner: Peter
# Jim (Paper) vs Zoe (Scissors) => Winner: Zoe
# Jane (Rock) vs Peter (Paper) => Winner: Peter
# Jane (Rock) vs Zoe (Scissors) => Winner: Jane
# Peter (Rock) vs Zoe (Paper) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 300 points
# Peter: 310 points
# Zoe: 354 points
#
#
# --- Round 25 ---
# Jim (Rock) vs Jane (Scissors) => Winner: Jim
# Jim (Scissors) vs Peter (Rock) => Winner: Peter
# Jim (Paper) vs Zoe (Rock) => Winner: Jim
# Jane (Paper) vs Peter (Paper) => Winner: Tie
# Jane (Rock) vs Zoe (Rock) => Winner: Tie
# Peter (Rock) vs Zoe (Paper) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 300 points
# Peter: 311 points
# Zoe: 355 points
#
#
# --- Round 26 ---
# Jim (Rock) vs Jane (Scissors) => Winner: Jim
# Jim (Rock) vs Peter (Scissors) => Winner: Jim
# Jim (Scissors) vs Zoe (Scissors) => Winner: Tie
# Jane (Scissors) vs Peter (Rock) => Winner: Peter
# Jane (Paper) vs Zoe (Rock) => Winner: Jane
# Peter (Rock) vs Zoe (Rock) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 300 points
# Peter: 312 points
# Zoe: 355 points
#
#
# --- Round 27 ---
# Jim (Rock) vs Jane (Rock) => Winner: Tie
# Jim (Rock) vs Peter (Scissors) => Winner: Jim
# Jim (Rock) vs Zoe (Paper) => Winner: Zoe
# Jane (Rock) vs Peter (Scissors) => Winner: Jane
# Jane (Rock) vs Zoe (Rock) => Winner: Tie
# Peter (Paper) vs Zoe (Paper) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 300 points
# Peter: 312 points
# Zoe: 356 points
#
#
# --- Round 28 ---
# Jim (Paper) vs Jane (Rock) => Winner: Jim
# Jim (Rock) vs Peter (Paper) => Winner: Peter
# Jim (Paper) vs Zoe (Paper) => Winner: Tie
# Jane (Rock) vs Peter (Scissors) => Winner: Jane
# Jane (Rock) vs Zoe (Paper) => Winner: Zoe
# Peter (Paper) vs Zoe (Rock) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 300 points
# Peter: 313 points
# Zoe: 357 points
#
#
# --- Round 29 ---
# Jim (Scissors) vs Jane (Paper) => Winner: Jim
# Jim (Rock) vs Peter (Scissors) => Winner: Jim
# Jim (Scissors) vs Zoe (Rock) => Winner: Zoe
# Jane (Rock) vs Peter (Scissors) => Winner: Jane
# Jane (Scissors) vs Zoe (Scissors) => Winner: Tie
# Peter (Rock) vs Zoe (Rock) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 300 points
# Peter: 313 points
# Zoe: 358 points
#
#
# --- Round 30 ---
# Jim (Scissors) vs Jane (Scissors) => Winner: Tie
# Jim (Scissors) vs Peter (Rock) => Winner: Peter
# Jim (Rock) vs Zoe (Scissors) => Winner: Jim
# Jane (Scissors) vs Peter (Paper) => Winner: Jane
# Jane (Scissors) vs Zoe (Rock) => Winner: Zoe
# Peter (Rock) vs Zoe (Scissors) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 300 points
# Peter: 314 points
# Zoe: 359 points
#
#
# --- Round 31 ---
# Jim (Rock) vs Jane (Paper) => Winner: Jane
# Jim (Rock) vs Peter (Paper) => Winner: Peter
# Jim (Rock) vs Zoe (Scissors) => Winner: Jim
# Jane (Scissors) vs Peter (Paper) => Winner: Jane
# Jane (Rock) vs Zoe (Scissors) => Winner: Jane
# Peter (Rock) vs Zoe (Paper) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 301 points
# Peter: 315 points
# Zoe: 360 points
#
#
# --- Round 32 ---
# Jim (Paper) vs Jane (Rock) => Winner: Jim
# Jim (Paper) vs Peter (Rock) => Winner: Jim
# Jim (Scissors) vs Zoe (Scissors) => Winner: Tie
# Jane (Rock) vs Peter (Rock) => Winner: Tie
# Jane (Rock) vs Zoe (Rock) => Winner: Tie
# Peter (Paper) vs Zoe (Paper) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 301 points
# Peter: 315 points
# Zoe: 360 points
#
#
# --- Round 33 ---
# Jim (Rock) vs Jane (Scissors) => Winner: Jim
# Jim (Rock) vs Peter (Paper) => Winner: Peter
# Jim (Rock) vs Zoe (Paper) => Winner: Zoe
# Jane (Paper) vs Peter (Paper) => Winner: Tie
# Jane (Scissors) vs Zoe (Rock) => Winner: Zoe
# Peter (Rock) vs Zoe (Rock) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 301 points
# Peter: 316 points
# Zoe: 362 points
#
#
# --- Round 34 ---
# Jim (Scissors) vs Jane (Rock) => Winner: Jane
# Jim (Scissors) vs Peter (Paper) => Winner: Jim
# Jim (Rock) vs Zoe (Rock) => Winner: Tie
# Jane (Rock) vs Peter (Paper) => Winner: Peter
# Jane (Paper) vs Zoe (Paper) => Winner: Tie
# Peter (Scissors) vs Zoe (Scissors) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 302 points
# Peter: 317 points
# Zoe: 362 points
#
#
# --- Round 35 ---
# Jim (Scissors) vs Jane (Paper) => Winner: Jim
# Jim (Scissors) vs Peter (Scissors) => Winner: Tie
# Jim (Scissors) vs Zoe (Scissors) => Winner: Tie
# Jane (Rock) vs Peter (Paper) => Winner: Peter
# Jane (Scissors) vs Zoe (Paper) => Winner: Jane
# Peter (Paper) vs Zoe (Paper) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 302 points
# Peter: 318 points
# Zoe: 362 points
#
#
# --- Round 36 ---
# Jim (Rock) vs Jane (Paper) => Winner: Jane
# Jim (Scissors) vs Peter (Rock) => Winner: Peter
# Jim (Paper) vs Zoe (Paper) => Winner: Tie
# Jane (Paper) vs Peter (Paper) => Winner: Tie
# Jane (Rock) vs Zoe (Scissors) => Winner: Jane
# Peter (Paper) vs Zoe (Paper) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 303 points
# Peter: 319 points
# Zoe: 362 points
#
#
# --- Round 37 ---
# Jim (Paper) vs Jane (Scissors) => Winner: Jane
# Jim (Rock) vs Peter (Scissors) => Winner: Jim
# Jim (Paper) vs Zoe (Paper) => Winner: Tie
# Jane (Paper) vs Peter (Paper) => Winner: Tie
# Jane (Scissors) vs Zoe (Rock) => Winner: Zoe
# Peter (Paper) vs Zoe (Scissors) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 304 points
# Peter: 319 points
# Zoe: 364 points
#
#
# --- Round 38 ---
# Jim (Rock) vs Jane (Scissors) => Winner: Jim
# Jim (Scissors) vs Peter (Rock) => Winner: Peter
# Jim (Scissors) vs Zoe (Paper) => Winner: Jim
# Jane (Paper) vs Peter (Scissors) => Winner: Peter
# Jane (Scissors) vs Zoe (Rock) => Winner: Zoe
# Peter (Rock) vs Zoe (Rock) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 304 points
# Peter: 321 points
# Zoe: 365 points
#
#
# --- Round 39 ---
# Jim (Paper) vs Jane (Rock) => Winner: Jim
# Jim (Scissors) vs Peter (Rock) => Winner: Peter
# Jim (Rock) vs Zoe (Rock) => Winner: Tie
# Jane (Paper) vs Peter (Scissors) => Winner: Peter
# Jane (Paper) vs Zoe (Rock) => Winner: Jane
# Peter (Scissors) vs Zoe (Scissors) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 304 points
# Peter: 323 points
# Zoe: 365 points
#
#
# --- Round 40 ---
# Jim (Scissors) vs Jane (Scissors) => Winner: Tie
# Jim (Rock) vs Peter (Rock) => Winner: Tie
# Jim (Paper) vs Zoe (Rock) => Winner: Jim
# Jane (Rock) vs Peter (Scissors) => Winner: Jane
# Jane (Paper) vs Zoe (Rock) => Winner: Jane
# Peter (Scissors) vs Zoe (Paper) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 304 points
# Peter: 323 points
# Zoe: 365 points
#
#
# --- Round 41 ---
# Jim (Rock) vs Jane (Scissors) => Winner: Jim
# Jim (Rock) vs Peter (Scissors) => Winner: Jim
# Jim (Paper) vs Zoe (Scissors) => Winner: Zoe
# Jane (Paper) vs Peter (Paper) => Winner: Tie
# Jane (Rock) vs Zoe (Rock) => Winner: Tie
# Peter (Rock) vs Zoe (Rock) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 304 points
# Peter: 323 points
# Zoe: 366 points
#
#
# --- Round 42 ---
# Jim (Scissors) vs Jane (Scissors) => Winner: Tie
# Jim (Paper) vs Peter (Rock) => Winner: Jim
# Jim (Paper) vs Zoe (Rock) => Winner: Jim
# Jane (Rock) vs Peter (Scissors) => Winner: Jane
# Jane (Paper) vs Zoe (Rock) => Winner: Jane
# Peter (Paper) vs Zoe (Scissors) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 304 points
# Peter: 323 points
# Zoe: 367 points
#
#
# --- Round 43 ---
# Jim (Paper) vs Jane (Scissors) => Winner: Jane
# Jim (Scissors) vs Peter (Rock) => Winner: Peter
# Jim (Rock) vs Zoe (Paper) => Winner: Zoe
# Jane (Rock) vs Peter (Paper) => Winner: Peter
# Jane (Paper) vs Zoe (Rock) => Winner: Jane
# Peter (Paper) vs Zoe (Scissors) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 305 points
# Peter: 325 points
# Zoe: 369 points
#
#
# --- Round 44 ---
# Jim (Rock) vs Jane (Rock) => Winner: Tie
# Jim (Rock) vs Peter (Paper) => Winner: Peter
# Jim (Paper) vs Zoe (Rock) => Winner: Jim
# Jane (Rock) vs Peter (Rock) => Winner: Tie
# Jane (Paper) vs Zoe (Rock) => Winner: Jane
# Peter (Paper) vs Zoe (Rock) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 305 points
# Peter: 326 points
# Zoe: 369 points
#
#
# --- Round 45 ---
# Jim (Rock) vs Jane (Scissors) => Winner: Jim
# Jim (Scissors) vs Peter (Paper) => Winner: Jim
# Jim (Paper) vs Zoe (Paper) => Winner: Tie
# Jane (Scissors) vs Peter (Paper) => Winner: Jane
# Jane (Scissors) vs Zoe (Rock) => Winner: Zoe
# Peter (Paper) vs Zoe (Rock) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 305 points
# Peter: 326 points
# Zoe: 370 points
#
#
# --- Round 46 ---
# Jim (Paper) vs Jane (Rock) => Winner: Jim
# Jim (Rock) vs Peter (Paper) => Winner: Peter
# Jim (Paper) vs Zoe (Scissors) => Winner: Zoe
# Jane (Rock) vs Peter (Paper) => Winner: Peter
# Jane (Rock) vs Zoe (Rock) => Winner: Tie
# Peter (Paper) vs Zoe (Scissors) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 305 points
# Peter: 328 points
# Zoe: 372 points
#
#
# --- Round 47 ---
# Jim (Scissors) vs Jane (Rock) => Winner: Jane
# Jim (Scissors) vs Peter (Scissors) => Winner: Tie
# Jim (Rock) vs Zoe (Rock) => Winner: Tie
# Jane (Paper) vs Peter (Scissors) => Winner: Peter
# Jane (Rock) vs Zoe (Rock) => Winner: Tie
# Peter (Scissors) vs Zoe (Scissors) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 306 points
# Peter: 329 points
# Zoe: 372 points
#
#
# --- Round 48 ---
# Jim (Paper) vs Jane (Rock) => Winner: Jim
# Jim (Scissors) vs Peter (Rock) => Winner: Peter
# Jim (Scissors) vs Zoe (Scissors) => Winner: Tie
# Jane (Paper) vs Peter (Rock) => Winner: Jane
# Jane (Scissors) vs Zoe (Scissors) => Winner: Tie
# Peter (Rock) vs Zoe (Scissors) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 306 points
# Peter: 330 points
# Zoe: 372 points
#
#
# --- Round 49 ---
# Jim (Scissors) vs Jane (Paper) => Winner: Jim
# Jim (Scissors) vs Peter (Paper) => Winner: Jim
# Jim (Paper) vs Zoe (Rock) => Winner: Jim
# Jane (Scissors) vs Peter (Paper) => Winner: Jane
# Jane (Rock) vs Zoe (Scissors) => Winner: Jane
# Peter (Scissors) vs Zoe (Scissors) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 306 points
# Peter: 330 points
# Zoe: 372 points
#
#
# --- Round 50 ---
# Jim (Paper) vs Jane (Paper) => Winner: Tie
# Jim (Rock) vs Peter (Scissors) => Winner: Jim
# Jim (Scissors) vs Zoe (Scissors) => Winner: Tie
# Jane (Scissors) vs Peter (Scissors) => Winner: Tie
# Jane (Scissors) vs Zoe (Scissors) => Winner: Tie
# Peter (Paper) vs Zoe (Paper) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 306 points
# Peter: 330 points
# Zoe: 372 points
#
#
# --- Round 51 ---
# Jim (Scissors) vs Jane (Rock) => Winner: Jane
# Jim (Rock) vs Peter (Rock) => Winner: Tie
# Jim (Scissors) vs Zoe (Scissors) => Winner: Tie
# Jane (Paper) vs Peter (Scissors) => Winner: Peter
# Jane (Rock) vs Zoe (Paper) => Winner: Zoe
# Peter (Paper) vs Zoe (Paper) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 307 points
# Peter: 331 points
# Zoe: 373 points
#
#
# --- Round 52 ---
# Jim (Rock) vs Jane (Paper) => Winner: Jane
# Jim (Paper) vs Peter (Scissors) => Winner: Peter
# Jim (Scissors) vs Zoe (Scissors) => Winner: Tie
# Jane (Rock) vs Peter (Paper) => Winner: Peter
# Jane (Paper) vs Zoe (Rock) => Winner: Jane
# Peter (Rock) vs Zoe (Scissors) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 308 points
# Peter: 333 points
# Zoe: 373 points
#
#
# --- Round 53 ---
# Jim (Rock) vs Jane (Scissors) => Winner: Jim
# Jim (Paper) vs Peter (Scissors) => Winner: Peter
# Jim (Paper) vs Zoe (Rock) => Winner: Jim
# Jane (Scissors) vs Peter (Rock) => Winner: Peter
# Jane (Rock) vs Zoe (Paper) => Winner: Zoe
# Peter (Rock) vs Zoe (Rock) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 308 points
# Peter: 335 points
# Zoe: 374 points
#
#
# --- Round 54 ---
# Jim (Rock) vs Jane (Scissors) => Winner: Jim
# Jim (Paper) vs Peter (Rock) => Winner: Jim
# Jim (Paper) vs Zoe (Scissors) => Winner: Zoe
# Jane (Rock) vs Peter (Rock) => Winner: Tie
# Jane (Paper) vs Zoe (Scissors) => Winner: Zoe
# Peter (Scissors) vs Zoe (Rock) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 308 points
# Peter: 335 points
# Zoe: 377 points
#
#
# --- Round 55 ---
# Jim (Scissors) vs Jane (Paper) => Winner: Jim
# Jim (Scissors) vs Peter (Rock) => Winner: Peter
# Jim (Scissors) vs Zoe (Scissors) => Winner: Tie
# Jane (Scissors) vs Peter (Paper) => Winner: Jane
# Jane (Paper) vs Zoe (Paper) => Winner: Tie
# Peter (Rock) vs Zoe (Paper) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 308 points
# Peter: 336 points
# Zoe: 378 points
#
#
# --- Round 56 ---
# Jim (Rock) vs Jane (Paper) => Winner: Jane
# Jim (Scissors) vs Peter (Rock) => Winner: Peter
# Jim (Paper) vs Zoe (Paper) => Winner: Tie
# Jane (Paper) vs Peter (Scissors) => Winner: Peter
# Jane (Scissors) vs Zoe (Paper) => Winner: Jane
# Peter (Rock) vs Zoe (Paper) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 309 points
# Peter: 338 points
# Zoe: 379 points
#
#
# --- Round 57 ---
# Jim (Rock) vs Jane (Paper) => Winner: Jane
# Jim (Scissors) vs Peter (Paper) => Winner: Jim
# Jim (Rock) vs Zoe (Paper) => Winner: Zoe
# Jane (Scissors) vs Peter (Paper) => Winner: Jane
# Jane (Paper) vs Zoe (Rock) => Winner: Jane
# Peter (Scissors) vs Zoe (Paper) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 310 points
# Peter: 338 points
# Zoe: 380 points
#
#
# --- Round 58 ---
# Jim (Rock) vs Jane (Paper) => Winner: Jane
# Jim (Paper) vs Peter (Rock) => Winner: Jim
# Jim (Scissors) vs Zoe (Paper) => Winner: Jim
# Jane (Rock) vs Peter (Paper) => Winner: Peter
# Jane (Paper) vs Zoe (Paper) => Winner: Tie
# Peter (Paper) vs Zoe (Scissors) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 311 points
# Peter: 339 points
# Zoe: 381 points
#
#
# --- Round 59 ---
# Jim (Scissors) vs Jane (Paper) => Winner: Jim
# Jim (Rock) vs Peter (Paper) => Winner: Peter
# Jim (Paper) vs Zoe (Paper) => Winner: Tie
# Jane (Rock) vs Peter (Rock) => Winner: Tie
# Jane (Scissors) vs Zoe (Paper) => Winner: Jane
# Peter (Rock) vs Zoe (Paper) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 311 points
# Peter: 340 points
# Zoe: 382 points
#
#
# --- Round 60 ---
# Jim (Rock) vs Jane (Rock) => Winner: Tie
# Jim (Scissors) vs Peter (Paper) => Winner: Jim
# Jim (Paper) vs Zoe (Rock) => Winner: Jim
# Jane (Scissors) vs Peter (Scissors) => Winner: Tie
# Jane (Scissors) vs Zoe (Paper) => Winner: Jane
# Peter (Paper) vs Zoe (Rock) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 311 points
# Peter: 340 points
# Zoe: 382 points
#
#
# --- Round 61 ---
# Jim (Rock) vs Jane (Paper) => Winner: Jane
# Jim (Rock) vs Peter (Paper) => Winner: Peter
# Jim (Rock) vs Zoe (Rock) => Winner: Tie
# Jane (Scissors) vs Peter (Scissors) => Winner: Tie
# Jane (Rock) vs Zoe (Rock) => Winner: Tie
# Peter (Rock) vs Zoe (Paper) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 312 points
# Peter: 341 points
# Zoe: 383 points
#
#
# --- Round 62 ---
# Jim (Rock) vs Jane (Paper) => Winner: Jane
# Jim (Scissors) vs Peter (Paper) => Winner: Jim
# Jim (Scissors) vs Zoe (Scissors) => Winner: Tie
# Jane (Rock) vs Peter (Rock) => Winner: Tie
# Jane (Scissors) vs Zoe (Rock) => Winner: Zoe
# Peter (Paper) vs Zoe (Scissors) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 313 points
# Peter: 341 points
# Zoe: 385 points
#
#
# --- Round 63 ---
# Jim (Paper) vs Jane (Rock) => Winner: Jim
# Jim (Paper) vs Peter (Paper) => Winner: Tie
# Jim (Scissors) vs Zoe (Rock) => Winner: Zoe
# Jane (Scissors) vs Peter (Paper) => Winner: Jane
# Jane (Rock) vs Zoe (Rock) => Winner: Tie
# Peter (Scissors) vs Zoe (Rock) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 313 points
# Peter: 341 points
# Zoe: 387 points
#
#
# --- Round 64 ---
# Jim (Paper) vs Jane (Paper) => Winner: Tie
# Jim (Scissors) vs Peter (Rock) => Winner: Peter
# Jim (Rock) vs Zoe (Scissors) => Winner: Jim
# Jane (Scissors) vs Peter (Rock) => Winner: Peter
# Jane (Rock) vs Zoe (Paper) => Winner: Zoe
# Peter (Paper) vs Zoe (Rock) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 313 points
# Peter: 343 points
# Zoe: 388 points
#
#
# --- Round 65 ---
# Jim (Rock) vs Jane (Paper) => Winner: Jane
# Jim (Rock) vs Peter (Rock) => Winner: Tie
# Jim (Scissors) vs Zoe (Rock) => Winner: Zoe
# Jane (Rock) vs Peter (Rock) => Winner: Tie
# Jane (Paper) vs Zoe (Scissors) => Winner: Zoe
# Peter (Paper) vs Zoe (Rock) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 314 points
# Peter: 343 points
# Zoe: 390 points
#
#
# --- Round 66 ---
# Jim (Rock) vs Jane (Paper) => Winner: Jane
# Jim (Rock) vs Peter (Scissors) => Winner: Jim
# Jim (Scissors) vs Zoe (Scissors) => Winner: Tie
# Jane (Paper) vs Peter (Rock) => Winner: Jane
# Jane (Paper) vs Zoe (Scissors) => Winner: Zoe
# Peter (Paper) vs Zoe (Rock) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 315 points
# Peter: 343 points
# Zoe: 391 points
#
#
# --- Round 67 ---
# Jim (Scissors) vs Jane (Paper) => Winner: Jim
# Jim (Paper) vs Peter (Scissors) => Winner: Peter
# Jim (Paper) vs Zoe (Paper) => Winner: Tie
# Jane (Paper) vs Peter (Scissors) => Winner: Peter
# Jane (Rock) vs Zoe (Paper) => Winner: Zoe
# Peter (Paper) vs Zoe (Paper) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 315 points
# Peter: 345 points
# Zoe: 392 points
#
#
# --- Round 68 ---
# Jim (Paper) vs Jane (Rock) => Winner: Jim
# Jim (Rock) vs Peter (Rock) => Winner: Tie
# Jim (Rock) vs Zoe (Rock) => Winner: Tie
# Jane (Paper) vs Peter (Scissors) => Winner: Peter
# Jane (Paper) vs Zoe (Paper) => Winner: Tie
# Peter (Scissors) vs Zoe (Paper) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 315 points
# Peter: 346 points
# Zoe: 392 points
#
#
# --- Round 69 ---
# Jim (Paper) vs Jane (Rock) => Winner: Jim
# Jim (Rock) vs Peter (Paper) => Winner: Peter
# Jim (Scissors) vs Zoe (Paper) => Winner: Jim
# Jane (Rock) vs Peter (Scissors) => Winner: Jane
# Jane (Paper) vs Zoe (Rock) => Winner: Jane
# Peter (Paper) vs Zoe (Rock) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 315 points
# Peter: 347 points
# Zoe: 392 points
#
#
# --- Round 70 ---
# Jim (Rock) vs Jane (Paper) => Winner: Jane
# Jim (Scissors) vs Peter (Scissors) => Winner: Tie
# Jim (Paper) vs Zoe (Paper) => Winner: Tie
# Jane (Paper) vs Peter (Paper) => Winner: Tie
# Jane (Rock) vs Zoe (Paper) => Winner: Zoe
# Peter (Scissors) vs Zoe (Scissors) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 316 points
# Peter: 347 points
# Zoe: 393 points
#
#
# --- Round 71 ---
# Jim (Scissors) vs Jane (Paper) => Winner: Jim
# Jim (Scissors) vs Peter (Rock) => Winner: Peter
# Jim (Rock) vs Zoe (Paper) => Winner: Zoe
# Jane (Rock) vs Peter (Rock) => Winner: Tie
# Jane (Scissors) vs Zoe (Paper) => Winner: Jane
# Peter (Paper) vs Zoe (Scissors) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 316 points
# Peter: 348 points
# Zoe: 395 points
#
#
# --- Round 72 ---
# Jim (Paper) vs Jane (Scissors) => Winner: Jane
# Jim (Paper) vs Peter (Paper) => Winner: Tie
# Jim (Scissors) vs Zoe (Paper) => Winner: Jim
# Jane (Rock) vs Peter (Paper) => Winner: Peter
# Jane (Scissors) vs Zoe (Scissors) => Winner: Tie
# Peter (Paper) vs Zoe (Paper) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 317 points
# Peter: 349 points
# Zoe: 395 points
#
#
# --- Round 73 ---
# Jim (Rock) vs Jane (Scissors) => Winner: Jim
# Jim (Rock) vs Peter (Paper) => Winner: Peter
# Jim (Rock) vs Zoe (Paper) => Winner: Zoe
# Jane (Rock) vs Peter (Paper) => Winner: Peter
# Jane (Rock) vs Zoe (Rock) => Winner: Tie
# Peter (Scissors) vs Zoe (Paper) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 317 points
# Peter: 351 points
# Zoe: 396 points
#
#
# --- Round 74 ---
# Jim (Paper) vs Jane (Rock) => Winner: Jim
# Jim (Scissors) vs Peter (Rock) => Winner: Peter
# Jim (Scissors) vs Zoe (Rock) => Winner: Zoe
# Jane (Scissors) vs Peter (Scissors) => Winner: Tie
# Jane (Scissors) vs Zoe (Paper) => Winner: Jane
# Peter (Rock) vs Zoe (Scissors) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 317 points
# Peter: 352 points
# Zoe: 397 points
#
#
# --- Round 75 ---
# Jim (Scissors) vs Jane (Scissors) => Winner: Tie
# Jim (Scissors) vs Peter (Rock) => Winner: Peter
# Jim (Scissors) vs Zoe (Paper) => Winner: Jim
# Jane (Scissors) vs Peter (Rock) => Winner: Peter
# Jane (Rock) vs Zoe (Scissors) => Winner: Jane
# Peter (Scissors) vs Zoe (Rock) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 317 points
# Peter: 354 points
# Zoe: 398 points
#
#
# --- Round 76 ---
# Jim (Scissors) vs Jane (Paper) => Winner: Jim
# Jim (Paper) vs Peter (Rock) => Winner: Jim
# Jim (Scissors) vs Zoe (Paper) => Winner: Jim
# Jane (Paper) vs Peter (Rock) => Winner: Jane
# Jane (Scissors) vs Zoe (Paper) => Winner: Jane
# Peter (Paper) vs Zoe (Rock) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 317 points
# Peter: 354 points
# Zoe: 398 points
#
#
# --- Round 77 ---
# Jim (Scissors) vs Jane (Rock) => Winner: Jane
# Jim (Scissors) vs Peter (Paper) => Winner: Jim
# Jim (Rock) vs Zoe (Scissors) => Winner: Jim
# Jane (Scissors) vs Peter (Paper) => Winner: Jane
# Jane (Scissors) vs Zoe (Scissors) => Winner: Tie
# Peter (Rock) vs Zoe (Rock) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 318 points
# Peter: 354 points
# Zoe: 398 points
#
#
# --- Round 78 ---
# Jim (Scissors) vs Jane (Paper) => Winner: Jim
# Jim (Scissors) vs Peter (Paper) => Winner: Jim
# Jim (Paper) vs Zoe (Rock) => Winner: Jim
# Jane (Paper) vs Peter (Scissors) => Winner: Peter
# Jane (Scissors) vs Zoe (Paper) => Winner: Jane
# Peter (Scissors) vs Zoe (Scissors) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 318 points
# Peter: 355 points
# Zoe: 398 points
#
#
# --- Round 79 ---
# Jim (Scissors) vs Jane (Scissors) => Winner: Tie
# Jim (Paper) vs Peter (Scissors) => Winner: Peter
# Jim (Paper) vs Zoe (Paper) => Winner: Tie
# Jane (Rock) vs Peter (Paper) => Winner: Peter
# Jane (Paper) vs Zoe (Paper) => Winner: Tie
# Peter (Scissors) vs Zoe (Paper) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 318 points
# Peter: 357 points
# Zoe: 398 points
#
#
# --- Round 80 ---
# Jim (Rock) vs Jane (Paper) => Winner: Jane
# Jim (Paper) vs Peter (Scissors) => Winner: Peter
# Jim (Rock) vs Zoe (Scissors) => Winner: Jim
# Jane (Rock) vs Peter (Scissors) => Winner: Jane
# Jane (Paper) vs Zoe (Scissors) => Winner: Zoe
# Peter (Paper) vs Zoe (Rock) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 319 points
# Peter: 358 points
# Zoe: 399 points
#
#
# --- Round 81 ---
# Jim (Paper) vs Jane (Scissors) => Winner: Jane
# Jim (Scissors) vs Peter (Scissors) => Winner: Tie
# Jim (Paper) vs Zoe (Scissors) => Winner: Zoe
# Jane (Paper) vs Peter (Paper) => Winner: Tie
# Jane (Rock) vs Zoe (Scissors) => Winner: Jane
# Peter (Rock) vs Zoe (Paper) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 320 points
# Peter: 358 points
# Zoe: 401 points
#
#
# --- Round 82 ---
# Jim (Rock) vs Jane (Rock) => Winner: Tie
# Jim (Scissors) vs Peter (Paper) => Winner: Jim
# Jim (Paper) vs Zoe (Rock) => Winner: Jim
# Jane (Paper) vs Peter (Rock) => Winner: Jane
# Jane (Paper) vs Zoe (Paper) => Winner: Tie
# Peter (Paper) vs Zoe (Scissors) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 320 points
# Peter: 358 points
# Zoe: 402 points
#
#
# --- Round 83 ---
# Jim (Paper) vs Jane (Paper) => Winner: Tie
# Jim (Paper) vs Peter (Rock) => Winner: Jim
# Jim (Scissors) vs Zoe (Paper) => Winner: Jim
# Jane (Rock) vs Peter (Paper) => Winner: Peter
# Jane (Scissors) vs Zoe (Paper) => Winner: Jane
# Peter (Paper) vs Zoe (Paper) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 320 points
# Peter: 359 points
# Zoe: 402 points
#
#
# --- Round 84 ---
# Jim (Rock) vs Jane (Scissors) => Winner: Jim
# Jim (Rock) vs Peter (Rock) => Winner: Tie
# Jim (Scissors) vs Zoe (Paper) => Winner: Jim
# Jane (Paper) vs Peter (Rock) => Winner: Jane
# Jane (Paper) vs Zoe (Paper) => Winner: Tie
# Peter (Rock) vs Zoe (Rock) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 320 points
# Peter: 359 points
# Zoe: 402 points
#
#
# --- Round 85 ---
# Jim (Rock) vs Jane (Paper) => Winner: Jane
# Jim (Scissors) vs Peter (Paper) => Winner: Jim
# Jim (Rock) vs Zoe (Paper) => Winner: Zoe
# Jane (Paper) vs Peter (Rock) => Winner: Jane
# Jane (Rock) vs Zoe (Paper) => Winner: Zoe
# Peter (Rock) vs Zoe (Paper) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 321 points
# Peter: 359 points
# Zoe: 405 points
#
#
# --- Round 86 ---
# Jim (Scissors) vs Jane (Rock) => Winner: Jane
# Jim (Scissors) vs Peter (Scissors) => Winner: Tie
# Jim (Scissors) vs Zoe (Scissors) => Winner: Tie
# Jane (Rock) vs Peter (Rock) => Winner: Tie
# Jane (Rock) vs Zoe (Rock) => Winner: Tie
# Peter (Rock) vs Zoe (Rock) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 322 points
# Peter: 359 points
# Zoe: 405 points
#
#
# --- Round 87 ---
# Jim (Rock) vs Jane (Rock) => Winner: Tie
# Jim (Rock) vs Peter (Paper) => Winner: Peter
# Jim (Rock) vs Zoe (Scissors) => Winner: Jim
# Jane (Rock) vs Peter (Scissors) => Winner: Jane
# Jane (Rock) vs Zoe (Paper) => Winner: Zoe
# Peter (Paper) vs Zoe (Rock) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 322 points
# Peter: 360 points
# Zoe: 406 points
#
#
# --- Round 88 ---
# Jim (Scissors) vs Jane (Scissors) => Winner: Tie
# Jim (Rock) vs Peter (Rock) => Winner: Tie
# Jim (Paper) vs Zoe (Rock) => Winner: Jim
# Jane (Rock) vs Peter (Rock) => Winner: Tie
# Jane (Rock) vs Zoe (Scissors) => Winner: Jane
# Peter (Paper) vs Zoe (Rock) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 322 points
# Peter: 360 points
# Zoe: 406 points
#
#
# --- Round 89 ---
# Jim (Scissors) vs Jane (Paper) => Winner: Jim
# Jim (Scissors) vs Peter (Rock) => Winner: Peter
# Jim (Rock) vs Zoe (Paper) => Winner: Zoe
# Jane (Rock) vs Peter (Rock) => Winner: Tie
# Jane (Scissors) vs Zoe (Rock) => Winner: Zoe
# Peter (Paper) vs Zoe (Rock) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 322 points
# Peter: 361 points
# Zoe: 408 points
#
#
# --- Round 90 ---
# Jim (Scissors) vs Jane (Scissors) => Winner: Tie
# Jim (Paper) vs Peter (Paper) => Winner: Tie
# Jim (Paper) vs Zoe (Paper) => Winner: Tie
# Jane (Scissors) vs Peter (Rock) => Winner: Peter
# Jane (Paper) vs Zoe (Rock) => Winner: Jane
# Peter (Paper) vs Zoe (Scissors) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 322 points
# Peter: 362 points
# Zoe: 409 points
#
#
# --- Round 91 ---
# Jim (Paper) vs Jane (Scissors) => Winner: Jane
# Jim (Rock) vs Peter (Scissors) => Winner: Jim
# Jim (Scissors) vs Zoe (Rock) => Winner: Zoe
# Jane (Scissors) vs Peter (Scissors) => Winner: Tie
# Jane (Paper) vs Zoe (Rock) => Winner: Jane
# Peter (Rock) vs Zoe (Scissors) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 323 points
# Peter: 362 points
# Zoe: 410 points
#
#
# --- Round 92 ---
# Jim (Paper) vs Jane (Paper) => Winner: Tie
# Jim (Paper) vs Peter (Rock) => Winner: Jim
# Jim (Paper) vs Zoe (Scissors) => Winner: Zoe
# Jane (Paper) vs Peter (Scissors) => Winner: Peter
# Jane (Scissors) vs Zoe (Scissors) => Winner: Tie
# Peter (Rock) vs Zoe (Scissors) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 323 points
# Peter: 363 points
# Zoe: 411 points
#
#
# --- Round 93 ---
# Jim (Rock) vs Jane (Scissors) => Winner: Jim
# Jim (Rock) vs Peter (Rock) => Winner: Tie
# Jim (Paper) vs Zoe (Scissors) => Winner: Zoe
# Jane (Paper) vs Peter (Paper) => Winner: Tie
# Jane (Rock) vs Zoe (Paper) => Winner: Zoe
# Peter (Rock) vs Zoe (Scissors) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 323 points
# Peter: 363 points
# Zoe: 413 points
#
#
# --- Round 94 ---
# Jim (Scissors) vs Jane (Scissors) => Winner: Tie
# Jim (Rock) vs Peter (Paper) => Winner: Peter
# Jim (Scissors) vs Zoe (Paper) => Winner: Jim
# Jane (Scissors) vs Peter (Scissors) => Winner: Tie
# Jane (Paper) vs Zoe (Rock) => Winner: Jane
# Peter (Scissors) vs Zoe (Rock) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 323 points
# Peter: 364 points
# Zoe: 414 points
#
#
# --- Round 95 ---
# Jim (Scissors) vs Jane (Scissors) => Winner: Tie
# Jim (Rock) vs Peter (Scissors) => Winner: Jim
# Jim (Paper) vs Zoe (Rock) => Winner: Jim
# Jane (Rock) vs Peter (Scissors) => Winner: Jane
# Jane (Rock) vs Zoe (Scissors) => Winner: Jane
# Peter (Paper) vs Zoe (Paper) => Winner: Tie
#
# Current Scores:
# Jim: 295 points
# Jane: 323 points
# Peter: 364 points
# Zoe: 414 points
#
#
# --- Round 96 ---
# Jim (Rock) vs Jane (Scissors) => Winner: Jim
# Jim (Rock) vs Peter (Paper) => Winner: Peter
# Jim (Scissors) vs Zoe (Paper) => Winner: Jim
# Jane (Paper) vs Peter (Rock) => Winner: Jane
# Jane (Paper) vs Zoe (Paper) => Winner: Tie
# Peter (Scissors) vs Zoe (Paper) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 323 points
# Peter: 365 points
# Zoe: 414 points
#
#
# --- Round 97 ---
# Jim (Paper) vs Jane (Paper) => Winner: Tie
# Jim (Rock) vs Peter (Rock) => Winner: Tie
# Jim (Paper) vs Zoe (Scissors) => Winner: Zoe
# Jane (Scissors) vs Peter (Rock) => Winner: Peter
# Jane (Scissors) vs Zoe (Paper) => Winner: Jane
# Peter (Paper) vs Zoe (Rock) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 323 points
# Peter: 366 points
# Zoe: 415 points
#
#
# --- Round 98 ---
# Jim (Scissors) vs Jane (Scissors) => Winner: Tie
# Jim (Paper) vs Peter (Rock) => Winner: Jim
# Jim (Rock) vs Zoe (Scissors) => Winner: Jim
# Jane (Scissors) vs Peter (Scissors) => Winner: Tie
# Jane (Rock) vs Zoe (Rock) => Winner: Tie
# Peter (Paper) vs Zoe (Rock) => Winner: Peter
#
# Current Scores:
# Jim: 295 points
# Jane: 323 points
# Peter: 366 points
# Zoe: 415 points
#
#
# --- Round 99 ---
# Jim (Rock) vs Jane (Paper) => Winner: Jane
# Jim (Paper) vs Peter (Rock) => Winner: Jim
# Jim (Rock) vs Zoe (Rock) => Winner: Tie
# Jane (Paper) vs Peter (Rock) => Winner: Jane
# Jane (Scissors) vs Zoe (Paper) => Winner: Jane
# Peter (Paper) vs Zoe (Scissors) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 324 points
# Peter: 366 points
# Zoe: 416 points
#
#
# --- Round 100 ---
# Jim (Paper) vs Jane (Rock) => Winner: Jim
# Jim (Scissors) vs Peter (Scissors) => Winner: Tie
# Jim (Rock) vs Zoe (Rock) => Winner: Tie
# Jane (Rock) vs Peter (Rock) => Winner: Tie
# Jane (Rock) vs Zoe (Rock) => Winner: Tie
# Peter (Scissors) vs Zoe (Rock) => Winner: Zoe
#
# Current Scores:
# Jim: 295 points
# Jane: 324 points
# Peter: 366 points
# Zoe: 417 points

# %%
# final situation
society
# Out:
# [{'name': 'Jim', 'score': 295, 'strategy': 'Rock'},
#  {'name': 'Jane', 'score': 324, 'strategy': 'Rock'},
#  {'name': 'Peter', 'score': 366, 'strategy': 'Scissors'},
#  {'name': 'Zoe', 'score': 417, 'strategy': 'Rock'}]

# %%
# as a data frame
socialResults=pd.DataFrame(society)
socialResults
# Out:
#     name  score  strategy
# 0    Jim    295      Rock
# 1   Jane    324      Rock
# 2  Peter    366  Scissors
# 3    Zoe    417      Rock

# %%
winnerScore=socialResults.score.max()

#social outcome
socialResults[socialResults.score==winnerScore]
# Out:
#   name  score strategy
# 0  Jim    106     Rock

# %% [markdown]
# ### Exercise 1
# <div class="alert-success">
#
# What code would you add  to see the live the results of this last tournament?
#
# </div>

# %% [markdown]
# ### Exercise 2
# <div class="alert-success">
#
# How would you implement this game for 10 players, and get the results?
#
# </div>
# <img src="https://i.imgur.com/DE5mjs4.jpg"/>

# %%
strategies = ['Rock', 'Paper', 'Scissors', 'Lizard', 'Spock']

# %%
payoff = {
    ('Rock', 'Scissors'): (1, 0), ('Scissors', 'Rock'): (0, 1),
    ('Rock', 'Lizard'): (1, 0), ('Lizard', 'Rock'): (0, 1),
    ('Scissors', 'Paper'): (1, 0), ('Paper', 'Scissors'): (0, 1),
    ('Paper', 'Rock'): (1, 0), ('Rock', 'Paper'): (0, 1),
    ('Lizard', 'Paper'): (1, 0), ('Paper', 'Lizard'): (0, 1),
    ('Spock', 'Scissors'): (1, 0), ('Scissors', 'Spock'): (0, 1),
    ('Spock', 'Rock'): (1, 0), ('Rock', 'Spock'): (0, 1),
    ('Lizard', 'Spock'): (1, 0), ('Spock', 'Lizard'): (0, 1),
    ('Scissors', 'Lizard'): (1, 0), ('Lizard', 'Scissors'): (0, 1),
    ('Paper', 'Spock'): (1, 0), ('Spock', 'Paper'): (0, 1),
    ('Rock', 'Rock'): (0, 0), ('Paper', 'Paper'): (0, 0),
    ('Scissors', 'Scissors'): (0, 0), ('Lizard', 'Lizard'): (0, 0),
    ('Spock', 'Spock'): (0, 0)
}

# %%
names = [
    "Mword", "Mari", "CarlosGOD", "Hisendo02", 
    "RomiGameplays", "Lukesize", "brunocerdan3", 
    "Jeni", "Annie", "SnoopiFredo"
]

# %%
society = [{'name': n, 'score': 0, 'strategy': None} for n in names]

# %%
society
# Out:
# [{'name': 'Mword', 'score': 0, 'strategy': None},
#  {'name': 'Mari', 'score': 0, 'strategy': None},
#  {'name': 'CarlosGOD', 'score': 0, 'strategy': None},
#  {'name': 'Hisendo02', 'score': 0, 'strategy': None},
#  {'name': 'RomiGameplays', 'score': 0, 'strategy': None},
#  {'name': 'Lukesize', 'score': 0, 'strategy': None},
#  {'name': 'brunocerdan3', 'score': 0, 'strategy': None},
#  {'name': 'Jeni', 'score': 0, 'strategy': None},
#  {'name': 'Annie', 'score': 0, 'strategy': None},
#  {'name': 'SnoopiFredo', 'score': 0, 'strategy': None}]

# %%
import itertools

# pair is a tuple of dicts
for pair in itertools.combinations(society,2):
    print(pair)
# Out:
# ({'name': 'Mword', 'score': 0, 'strategy': None}, {'name': 'Mari', 'score': 0, 'strategy': None})
# ({'name': 'Mword', 'score': 0, 'strategy': None}, {'name': 'CarlosGOD', 'score': 0, 'strategy': None})
# ({'name': 'Mword', 'score': 0, 'strategy': None}, {'name': 'Hisendo02', 'score': 0, 'strategy': None})
# ({'name': 'Mword', 'score': 0, 'strategy': None}, {'name': 'RomiGameplays', 'score': 0, 'strategy': None})
# ({'name': 'Mword', 'score': 0, 'strategy': None}, {'name': 'Lukesize', 'score': 0, 'strategy': None})
# ({'name': 'Mword', 'score': 0, 'strategy': None}, {'name': 'brunocerdan3', 'score': 0, 'strategy': None})
# ({'name': 'Mword', 'score': 0, 'strategy': None}, {'name': 'Jeni', 'score': 0, 'strategy': None})
# ({'name': 'Mword', 'score': 0, 'strategy': None}, {'name': 'Annie', 'score': 0, 'strategy': None})
# ({'name': 'Mword', 'score': 0, 'strategy': None}, {'name': 'SnoopiFredo', 'score': 0, 'strategy': None})
# ({'name': 'Mari', 'score': 0, 'strategy': None}, {'name': 'CarlosGOD', 'score': 0, 'strategy': None})
# ({'name': 'Mari', 'score': 0, 'strategy': None}, {'name': 'Hisendo02', 'score': 0, 'strategy': None})
# ({'name': 'Mari', 'score': 0, 'strategy': None}, {'name': 'RomiGameplays', 'score': 0, 'strategy': None})
# ({'name': 'Mari', 'score': 0, 'strategy': None}, {'name': 'Lukesize', 'score': 0, 'strategy': None})
# ({'name': 'Mari', 'score': 0, 'strategy': None}, {'name': 'brunocerdan3', 'score': 0, 'strategy': None})
# ({'name': 'Mari', 'score': 0, 'strategy': None}, {'name': 'Jeni', 'score': 0, 'strategy': None})
# ({'name': 'Mari', 'score': 0, 'strategy': None}, {'name': 'Annie', 'score': 0, 'strategy': None})
# ({'name': 'Mari', 'score': 0, 'strategy': None}, {'name': 'SnoopiFredo', 'score': 0, 'strategy': None})
# ({'name': 'CarlosGOD', 'score': 0, 'strategy': None}, {'name': 'Hisendo02', 'score': 0, 'strategy': None})
# ({'name': 'CarlosGOD', 'score': 0, 'strategy': None}, {'name': 'RomiGameplays', 'score': 0, 'strategy': None})
# ({'name': 'CarlosGOD', 'score': 0, 'strategy': None}, {'name': 'Lukesize', 'score': 0, 'strategy': None})
# ({'name': 'CarlosGOD', 'score': 0, 'strategy': None}, {'name': 'brunocerdan3', 'score': 0, 'strategy': None})
# ({'name': 'CarlosGOD', 'score': 0, 'strategy': None}, {'name': 'Jeni', 'score': 0, 'strategy': None})
# ({'name': 'CarlosGOD', 'score': 0, 'strategy': None}, {'name': 'Annie', 'score': 0, 'strategy': None})
# ({'name': 'CarlosGOD', 'score': 0, 'strategy': None}, {'name': 'SnoopiFredo', 'score': 0, 'strategy': None})
# ({'name': 'Hisendo02', 'score': 0, 'strategy': None}, {'name': 'RomiGameplays', 'score': 0, 'strategy': None})
# ({'name': 'Hisendo02', 'score': 0, 'strategy': None}, {'name': 'Lukesize', 'score': 0, 'strategy': None})
# ({'name': 'Hisendo02', 'score': 0, 'strategy': None}, {'name': 'brunocerdan3', 'score': 0, 'strategy': None})
# ({'name': 'Hisendo02', 'score': 0, 'strategy': None}, {'name': 'Jeni', 'score': 0, 'strategy': None})
# ({'name': 'Hisendo02', 'score': 0, 'strategy': None}, {'name': 'Annie', 'score': 0, 'strategy': None})
# ({'name': 'Hisendo02', 'score': 0, 'strategy': None}, {'name': 'SnoopiFredo', 'score': 0, 'strategy': None})
# ({'name': 'RomiGameplays', 'score': 0, 'strategy': None}, {'name': 'Lukesize', 'score': 0, 'strategy': None})
# ({'name': 'RomiGameplays', 'score': 0, 'strategy': None}, {'name': 'brunocerdan3', 'score': 0, 'strategy': None})
# ({'name': 'RomiGameplays', 'score': 0, 'strategy': None}, {'name': 'Jeni', 'score': 0, 'strategy': None})
# ({'name': 'RomiGameplays', 'score': 0, 'strategy': None}, {'name': 'Annie', 'score': 0, 'strategy': None})
# ({'name': 'RomiGameplays', 'score': 0, 'strategy': None}, {'name': 'SnoopiFredo', 'score': 0, 'strategy': None})
# ({'name': 'Lukesize', 'score': 0, 'strategy': None}, {'name': 'brunocerdan3', 'score': 0, 'strategy': None})
# ({'name': 'Lukesize', 'score': 0, 'strategy': None}, {'name': 'Jeni', 'score': 0, 'strategy': None})
# ({'name': 'Lukesize', 'score': 0, 'strategy': None}, {'name': 'Annie', 'score': 0, 'strategy': None})
# ({'name': 'Lukesize', 'score': 0, 'strategy': None}, {'name': 'SnoopiFredo', 'score': 0, 'strategy': None})
# ({'name': 'brunocerdan3', 'score': 0, 'strategy': None}, {'name': 'Jeni', 'score': 0, 'strategy': None})
# ({'name': 'brunocerdan3', 'score': 0, 'strategy': None}, {'name': 'Annie', 'score': 0, 'strategy': None})
# ({'name': 'brunocerdan3', 'score': 0, 'strategy': None}, {'name': 'SnoopiFredo', 'score': 0, 'strategy': None})
# ({'name': 'Jeni', 'score': 0, 'strategy': None}, {'name': 'Annie', 'score': 0, 'strategy': None})
# ({'name': 'Jeni', 'score': 0, 'strategy': None}, {'name': 'SnoopiFredo', 'score': 0, 'strategy': None})
# ({'name': 'Annie', 'score': 0, 'strategy': None}, {'name': 'SnoopiFredo', 'score': 0, 'strategy': None})

# %%
import itertools

# each dict
for player1,player2 in itertools.combinations(society,2):
    print(player1,player2)
# Out:
# {'name': 'Mword', 'score': 0, 'strategy': None} {'name': 'Mari', 'score': 0, 'strategy': None}
# {'name': 'Mword', 'score': 0, 'strategy': None} {'name': 'CarlosGOD', 'score': 0, 'strategy': None}
# {'name': 'Mword', 'score': 0, 'strategy': None} {'name': 'Hisendo02', 'score': 0, 'strategy': None}
# {'name': 'Mword', 'score': 0, 'strategy': None} {'name': 'RomiGameplays', 'score': 0, 'strategy': None}
# {'name': 'Mword', 'score': 0, 'strategy': None} {'name': 'Lukesize', 'score': 0, 'strategy': None}
# {'name': 'Mword', 'score': 0, 'strategy': None} {'name': 'brunocerdan3', 'score': 0, 'strategy': None}
# {'name': 'Mword', 'score': 0, 'strategy': None} {'name': 'Jeni', 'score': 0, 'strategy': None}
# {'name': 'Mword', 'score': 0, 'strategy': None} {'name': 'Annie', 'score': 0, 'strategy': None}
# {'name': 'Mword', 'score': 0, 'strategy': None} {'name': 'SnoopiFredo', 'score': 0, 'strategy': None}
# {'name': 'Mari', 'score': 0, 'strategy': None} {'name': 'CarlosGOD', 'score': 0, 'strategy': None}
# {'name': 'Mari', 'score': 0, 'strategy': None} {'name': 'Hisendo02', 'score': 0, 'strategy': None}
# {'name': 'Mari', 'score': 0, 'strategy': None} {'name': 'RomiGameplays', 'score': 0, 'strategy': None}
# {'name': 'Mari', 'score': 0, 'strategy': None} {'name': 'Lukesize', 'score': 0, 'strategy': None}
# {'name': 'Mari', 'score': 0, 'strategy': None} {'name': 'brunocerdan3', 'score': 0, 'strategy': None}
# {'name': 'Mari', 'score': 0, 'strategy': None} {'name': 'Jeni', 'score': 0, 'strategy': None}
# {'name': 'Mari', 'score': 0, 'strategy': None} {'name': 'Annie', 'score': 0, 'strategy': None}
# {'name': 'Mari', 'score': 0, 'strategy': None} {'name': 'SnoopiFredo', 'score': 0, 'strategy': None}
# {'name': 'CarlosGOD', 'score': 0, 'strategy': None} {'name': 'Hisendo02', 'score': 0, 'strategy': None}
# {'name': 'CarlosGOD', 'score': 0, 'strategy': None} {'name': 'RomiGameplays', 'score': 0, 'strategy': None}
# {'name': 'CarlosGOD', 'score': 0, 'strategy': None} {'name': 'Lukesize', 'score': 0, 'strategy': None}
# {'name': 'CarlosGOD', 'score': 0, 'strategy': None} {'name': 'brunocerdan3', 'score': 0, 'strategy': None}
# {'name': 'CarlosGOD', 'score': 0, 'strategy': None} {'name': 'Jeni', 'score': 0, 'strategy': None}
# {'name': 'CarlosGOD', 'score': 0, 'strategy': None} {'name': 'Annie', 'score': 0, 'strategy': None}
# {'name': 'CarlosGOD', 'score': 0, 'strategy': None} {'name': 'SnoopiFredo', 'score': 0, 'strategy': None}
# {'name': 'Hisendo02', 'score': 0, 'strategy': None} {'name': 'RomiGameplays', 'score': 0, 'strategy': None}
# {'name': 'Hisendo02', 'score': 0, 'strategy': None} {'name': 'Lukesize', 'score': 0, 'strategy': None}
# {'name': 'Hisendo02', 'score': 0, 'strategy': None} {'name': 'brunocerdan3', 'score': 0, 'strategy': None}
# {'name': 'Hisendo02', 'score': 0, 'strategy': None} {'name': 'Jeni', 'score': 0, 'strategy': None}
# {'name': 'Hisendo02', 'score': 0, 'strategy': None} {'name': 'Annie', 'score': 0, 'strategy': None}
# {'name': 'Hisendo02', 'score': 0, 'strategy': None} {'name': 'SnoopiFredo', 'score': 0, 'strategy': None}
# {'name': 'RomiGameplays', 'score': 0, 'strategy': None} {'name': 'Lukesize', 'score': 0, 'strategy': None}
# {'name': 'RomiGameplays', 'score': 0, 'strategy': None} {'name': 'brunocerdan3', 'score': 0, 'strategy': None}
# {'name': 'RomiGameplays', 'score': 0, 'strategy': None} {'name': 'Jeni', 'score': 0, 'strategy': None}
# {'name': 'RomiGameplays', 'score': 0, 'strategy': None} {'name': 'Annie', 'score': 0, 'strategy': None}
# {'name': 'RomiGameplays', 'score': 0, 'strategy': None} {'name': 'SnoopiFredo', 'score': 0, 'strategy': None}
# {'name': 'Lukesize', 'score': 0, 'strategy': None} {'name': 'brunocerdan3', 'score': 0, 'strategy': None}
# {'name': 'Lukesize', 'score': 0, 'strategy': None} {'name': 'Jeni', 'score': 0, 'strategy': None}
# {'name': 'Lukesize', 'score': 0, 'strategy': None} {'name': 'Annie', 'score': 0, 'strategy': None}
# {'name': 'Lukesize', 'score': 0, 'strategy': None} {'name': 'SnoopiFredo', 'score': 0, 'strategy': None}
# {'name': 'brunocerdan3', 'score': 0, 'strategy': None} {'name': 'Jeni', 'score': 0, 'strategy': None}
# {'name': 'brunocerdan3', 'score': 0, 'strategy': None} {'name': 'Annie', 'score': 0, 'strategy': None}
# {'name': 'brunocerdan3', 'score': 0, 'strategy': None} {'name': 'SnoopiFredo', 'score': 0, 'strategy': None}
# {'name': 'Jeni', 'score': 0, 'strategy': None} {'name': 'Annie', 'score': 0, 'strategy': None}
# {'name': 'Jeni', 'score': 0, 'strategy': None} {'name': 'SnoopiFredo', 'score': 0, 'strategy': None}
# {'name': 'Annie', 'score': 0, 'strategy': None} {'name': 'SnoopiFredo', 'score': 0, 'strategy': None}

# %%
for aRound in range(100):  # Adjust the number of rounds as needed
    print(f"--- Round {aRound + 1} ---")

    for player1, player2 in itertools.combinations(society, 2):
        # Each player chooses a random strategy
        player1['strategy'] = choice(strategies)
        player2['strategy'] = choice(strategies)

        # Get the result based on the strategies
        result = payoff[(player1['strategy'], player2['strategy'])]

        # Update scores
        player1['score'] += result[0]
        player2['score'] += result[1]

        # Print match result
        winner = "Tie"
        if result[0] > result[1]:
            winner = player1['name']
        elif result[1] > result[0]:
            winner = player2['name']

        print(f"{player1['name']} ({player1['strategy']}) vs {player2['name']} ({player2['strategy']}) => Winner: {winner}")

    # Print the scores after the round
    print("\nCurrent Scores:")
    for player in society:
        print(f"{player['name']}: {player['score']} points")
    print("\n")

# Convert results to DataFrame and determine the winner
socialResults = pd.DataFrame(society)
winnerScore = socialResults.score.max()
print("--- Final Results ---")
print(socialResults)
print(f"Winner(s):")
print(socialResults[socialResults.score == winnerScore])
# Out:
# --- Round 1 ---
# Mword (Scissors) vs Mari (Scissors) => Winner: Tie
# Mword (Lizard) vs CarlosGOD (Spock) => Winner: Mword
# Mword (Spock) vs Hisendo02 (Rock) => Winner: Mword
# Mword (Paper) vs RomiGameplays (Rock) => Winner: Mword
# Mword (Scissors) vs Lukesize (Spock) => Winner: Lukesize
# Mword (Rock) vs brunocerdan3 (Scissors) => Winner: Mword
# Mword (Paper) vs Jeni (Scissors) => Winner: Jeni
# Mword (Lizard) vs Annie (Rock) => Winner: Annie
# Mword (Lizard) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# Mari (Scissors) vs CarlosGOD (Lizard) => Winner: Mari
# Mari (Rock) vs Hisendo02 (Paper) => Winner: Hisendo02
# Mari (Lizard) vs RomiGameplays (Lizard) => Winner: Tie
# Mari (Paper) vs Lukesize (Scissors) => Winner: Lukesize
# Mari (Paper) vs brunocerdan3 (Lizard) => Winner: brunocerdan3
# Mari (Rock) vs Jeni (Rock) => Winner: Tie
# Mari (Scissors) vs Annie (Scissors) => Winner: Tie
# Mari (Scissors) vs SnoopiFredo (Lizard) => Winner: Mari
# CarlosGOD (Spock) vs Hisendo02 (Lizard) => Winner: Hisendo02
# CarlosGOD (Spock) vs RomiGameplays (Spock) => Winner: Tie
# CarlosGOD (Scissors) vs Lukesize (Rock) => Winner: Lukesize
# CarlosGOD (Lizard) vs brunocerdan3 (Rock) => Winner: brunocerdan3
# CarlosGOD (Paper) vs Jeni (Scissors) => Winner: Jeni
# CarlosGOD (Rock) vs Annie (Scissors) => Winner: CarlosGOD
# CarlosGOD (Paper) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# Hisendo02 (Paper) vs RomiGameplays (Rock) => Winner: Hisendo02
# Hisendo02 (Rock) vs Lukesize (Spock) => Winner: Lukesize
# Hisendo02 (Lizard) vs brunocerdan3 (Rock) => Winner: brunocerdan3
# Hisendo02 (Spock) vs Jeni (Lizard) => Winner: Jeni
# Hisendo02 (Lizard) vs Annie (Scissors) => Winner: Annie
# Hisendo02 (Lizard) vs SnoopiFredo (Rock) => Winner: SnoopiFredo
# RomiGameplays (Spock) vs Lukesize (Lizard) => Winner: Lukesize
# RomiGameplays (Lizard) vs brunocerdan3 (Paper) => Winner: RomiGameplays
# RomiGameplays (Rock) vs Jeni (Lizard) => Winner: RomiGameplays
# RomiGameplays (Spock) vs Annie (Paper) => Winner: Annie
# RomiGameplays (Scissors) vs SnoopiFredo (Paper) => Winner: RomiGameplays
# Lukesize (Spock) vs brunocerdan3 (Rock) => Winner: Lukesize
# Lukesize (Spock) vs Jeni (Paper) => Winner: Jeni
# Lukesize (Scissors) vs Annie (Scissors) => Winner: Tie
# Lukesize (Scissors) vs SnoopiFredo (Paper) => Winner: Lukesize
# brunocerdan3 (Paper) vs Jeni (Spock) => Winner: brunocerdan3
# brunocerdan3 (Scissors) vs Annie (Paper) => Winner: brunocerdan3
# brunocerdan3 (Scissors) vs SnoopiFredo (Paper) => Winner: brunocerdan3
# Jeni (Spock) vs Annie (Spock) => Winner: Tie
# Jeni (Paper) vs SnoopiFredo (Rock) => Winner: Jeni
# Annie (Spock) vs SnoopiFredo (Rock) => Winner: Annie
#
# Current Scores:
# Mword: 4 points
# Mari: 2 points
# CarlosGOD: 1 points
# Hisendo02: 3 points
# RomiGameplays: 3 points
# Lukesize: 7 points
# brunocerdan3: 6 points
# Jeni: 5 points
# Annie: 4 points
# SnoopiFredo: 3 points
#
#
# --- Round 2 ---
# Mword (Rock) vs Mari (Lizard) => Winner: Mword
# Mword (Rock) vs CarlosGOD (Rock) => Winner: Tie
# Mword (Lizard) vs Hisendo02 (Paper) => Winner: Mword
# Mword (Scissors) vs RomiGameplays (Spock) => Winner: RomiGameplays
# Mword (Scissors) vs Lukesize (Lizard) => Winner: Mword
# Mword (Scissors) vs brunocerdan3 (Lizard) => Winner: Mword
# Mword (Scissors) vs Jeni (Lizard) => Winner: Mword
# Mword (Spock) vs Annie (Paper) => Winner: Annie
# Mword (Rock) vs SnoopiFredo (Spock) => Winner: SnoopiFredo
# Mari (Paper) vs CarlosGOD (Paper) => Winner: Tie
# Mari (Rock) vs Hisendo02 (Spock) => Winner: Hisendo02
# Mari (Paper) vs RomiGameplays (Lizard) => Winner: RomiGameplays
# Mari (Lizard) vs Lukesize (Paper) => Winner: Mari
# Mari (Scissors) vs brunocerdan3 (Rock) => Winner: brunocerdan3
# Mari (Scissors) vs Jeni (Scissors) => Winner: Tie
# Mari (Paper) vs Annie (Spock) => Winner: Mari
# Mari (Spock) vs SnoopiFredo (Scissors) => Winner: Mari
# CarlosGOD (Rock) vs Hisendo02 (Rock) => Winner: Tie
# CarlosGOD (Lizard) vs RomiGameplays (Paper) => Winner: CarlosGOD
# CarlosGOD (Lizard) vs Lukesize (Scissors) => Winner: Lukesize
# CarlosGOD (Spock) vs brunocerdan3 (Lizard) => Winner: brunocerdan3
# CarlosGOD (Paper) vs Jeni (Lizard) => Winner: Jeni
# CarlosGOD (Paper) vs Annie (Rock) => Winner: CarlosGOD
# CarlosGOD (Paper) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# Hisendo02 (Scissors) vs RomiGameplays (Scissors) => Winner: Tie
# Hisendo02 (Spock) vs Lukesize (Lizard) => Winner: Lukesize
# Hisendo02 (Lizard) vs brunocerdan3 (Rock) => Winner: brunocerdan3
# Hisendo02 (Spock) vs Jeni (Paper) => Winner: Jeni
# Hisendo02 (Paper) vs Annie (Paper) => Winner: Tie
# Hisendo02 (Scissors) vs SnoopiFredo (Paper) => Winner: Hisendo02
# RomiGameplays (Paper) vs Lukesize (Paper) => Winner: Tie
# RomiGameplays (Lizard) vs brunocerdan3 (Spock) => Winner: RomiGameplays
# RomiGameplays (Rock) vs Jeni (Rock) => Winner: Tie
# RomiGameplays (Rock) vs Annie (Paper) => Winner: Annie
# RomiGameplays (Spock) vs SnoopiFredo (Scissors) => Winner: RomiGameplays
# Lukesize (Lizard) vs brunocerdan3 (Lizard) => Winner: Tie
# Lukesize (Scissors) vs Jeni (Rock) => Winner: Jeni
# Lukesize (Spock) vs Annie (Paper) => Winner: Annie
# Lukesize (Scissors) vs SnoopiFredo (Rock) => Winner: SnoopiFredo
# brunocerdan3 (Paper) vs Jeni (Paper) => Winner: Tie
# brunocerdan3 (Rock) vs Annie (Rock) => Winner: Tie
# brunocerdan3 (Lizard) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# Jeni (Spock) vs Annie (Spock) => Winner: Tie
# Jeni (Scissors) vs SnoopiFredo (Scissors) => Winner: Tie
# Annie (Rock) vs SnoopiFredo (Scissors) => Winner: Annie
#
# Current Scores:
# Mword: 9 points
# Mari: 5 points
# CarlosGOD: 3 points
# Hisendo02: 5 points
# RomiGameplays: 7 points
# Lukesize: 9 points
# brunocerdan3: 9 points
# Jeni: 8 points
# Annie: 8 points
# SnoopiFredo: 7 points
#
#
# --- Round 3 ---
# Mword (Scissors) vs Mari (Spock) => Winner: Mari
# Mword (Lizard) vs CarlosGOD (Paper) => Winner: Mword
# Mword (Paper) vs Hisendo02 (Paper) => Winner: Tie
# Mword (Paper) vs RomiGameplays (Spock) => Winner: Mword
# Mword (Rock) vs Lukesize (Paper) => Winner: Lukesize
# Mword (Scissors) vs brunocerdan3 (Paper) => Winner: Mword
# Mword (Spock) vs Jeni (Rock) => Winner: Mword
# Mword (Spock) vs Annie (Spock) => Winner: Tie
# Mword (Lizard) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# Mari (Spock) vs CarlosGOD (Rock) => Winner: Mari
# Mari (Scissors) vs Hisendo02 (Paper) => Winner: Mari
# Mari (Paper) vs RomiGameplays (Scissors) => Winner: RomiGameplays
# Mari (Spock) vs Lukesize (Scissors) => Winner: Mari
# Mari (Rock) vs brunocerdan3 (Paper) => Winner: brunocerdan3
# Mari (Scissors) vs Jeni (Spock) => Winner: Jeni
# Mari (Lizard) vs Annie (Lizard) => Winner: Tie
# Mari (Spock) vs SnoopiFredo (Rock) => Winner: Mari
# CarlosGOD (Paper) vs Hisendo02 (Lizard) => Winner: Hisendo02
# CarlosGOD (Paper) vs RomiGameplays (Lizard) => Winner: RomiGameplays
# CarlosGOD (Scissors) vs Lukesize (Paper) => Winner: CarlosGOD
# CarlosGOD (Paper) vs brunocerdan3 (Lizard) => Winner: brunocerdan3
# CarlosGOD (Scissors) vs Jeni (Spock) => Winner: Jeni
# CarlosGOD (Paper) vs Annie (Scissors) => Winner: Annie
# CarlosGOD (Scissors) vs SnoopiFredo (Scissors) => Winner: Tie
# Hisendo02 (Paper) vs RomiGameplays (Spock) => Winner: Hisendo02
# Hisendo02 (Spock) vs Lukesize (Spock) => Winner: Tie
# Hisendo02 (Lizard) vs brunocerdan3 (Scissors) => Winner: brunocerdan3
# Hisendo02 (Scissors) vs Jeni (Spock) => Winner: Jeni
# Hisendo02 (Lizard) vs Annie (Spock) => Winner: Hisendo02
# Hisendo02 (Rock) vs SnoopiFredo (Lizard) => Winner: Hisendo02
# RomiGameplays (Paper) vs Lukesize (Scissors) => Winner: Lukesize
# RomiGameplays (Lizard) vs brunocerdan3 (Spock) => Winner: RomiGameplays
# RomiGameplays (Scissors) vs Jeni (Lizard) => Winner: RomiGameplays
# RomiGameplays (Lizard) vs Annie (Scissors) => Winner: Annie
# RomiGameplays (Lizard) vs SnoopiFredo (Spock) => Winner: RomiGameplays
# Lukesize (Paper) vs brunocerdan3 (Rock) => Winner: Lukesize
# Lukesize (Lizard) vs Jeni (Scissors) => Winner: Jeni
# Lukesize (Rock) vs Annie (Rock) => Winner: Tie
# Lukesize (Spock) vs SnoopiFredo (Spock) => Winner: Tie
# brunocerdan3 (Scissors) vs Jeni (Lizard) => Winner: brunocerdan3
# brunocerdan3 (Spock) vs Annie (Lizard) => Winner: Annie
# brunocerdan3 (Scissors) vs SnoopiFredo (Rock) => Winner: SnoopiFredo
# Jeni (Scissors) vs Annie (Paper) => Winner: Jeni
# Jeni (Rock) vs SnoopiFredo (Lizard) => Winner: Jeni
# Annie (Paper) vs SnoopiFredo (Paper) => Winner: Tie
#
# Current Scores:
# Mword: 13 points
# Mari: 10 points
# CarlosGOD: 4 points
# Hisendo02: 9 points
# RomiGameplays: 12 points
# Lukesize: 12 points
# brunocerdan3: 13 points
# Jeni: 14 points
# Annie: 11 points
# SnoopiFredo: 9 points
#
#
# --- Round 4 ---
# Mword (Paper) vs Mari (Scissors) => Winner: Mari
# Mword (Spock) vs CarlosGOD (Spock) => Winner: Tie
# Mword (Spock) vs Hisendo02 (Rock) => Winner: Mword
# Mword (Lizard) vs RomiGameplays (Spock) => Winner: Mword
# Mword (Spock) vs Lukesize (Lizard) => Winner: Lukesize
# Mword (Lizard) vs brunocerdan3 (Rock) => Winner: brunocerdan3
# Mword (Scissors) vs Jeni (Scissors) => Winner: Tie
# Mword (Scissors) vs Annie (Spock) => Winner: Annie
# Mword (Rock) vs SnoopiFredo (Paper) => Winner: SnoopiFredo
# Mari (Rock) vs CarlosGOD (Paper) => Winner: CarlosGOD
# Mari (Scissors) vs Hisendo02 (Scissors) => Winner: Tie
# Mari (Spock) vs RomiGameplays (Paper) => Winner: RomiGameplays
# Mari (Paper) vs Lukesize (Scissors) => Winner: Lukesize
# Mari (Paper) vs brunocerdan3 (Scissors) => Winner: brunocerdan3
# Mari (Rock) vs Jeni (Spock) => Winner: Jeni
# Mari (Paper) vs Annie (Lizard) => Winner: Annie
# Mari (Paper) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# CarlosGOD (Scissors) vs Hisendo02 (Scissors) => Winner: Tie
# CarlosGOD (Paper) vs RomiGameplays (Lizard) => Winner: RomiGameplays
# CarlosGOD (Rock) vs Lukesize (Lizard) => Winner: CarlosGOD
# CarlosGOD (Paper) vs brunocerdan3 (Paper) => Winner: Tie
# CarlosGOD (Scissors) vs Jeni (Lizard) => Winner: CarlosGOD
# CarlosGOD (Rock) vs Annie (Paper) => Winner: Annie
# CarlosGOD (Scissors) vs SnoopiFredo (Lizard) => Winner: CarlosGOD
# Hisendo02 (Spock) vs RomiGameplays (Paper) => Winner: RomiGameplays
# Hisendo02 (Lizard) vs Lukesize (Paper) => Winner: Hisendo02
# Hisendo02 (Spock) vs brunocerdan3 (Rock) => Winner: Hisendo02
# Hisendo02 (Rock) vs Jeni (Spock) => Winner: Jeni
# Hisendo02 (Scissors) vs Annie (Scissors) => Winner: Tie
# Hisendo02 (Scissors) vs SnoopiFredo (Paper) => Winner: Hisendo02
# RomiGameplays (Spock) vs Lukesize (Paper) => Winner: Lukesize
# RomiGameplays (Scissors) vs brunocerdan3 (Scissors) => Winner: Tie
# RomiGameplays (Spock) vs Jeni (Scissors) => Winner: RomiGameplays
# RomiGameplays (Lizard) vs Annie (Spock) => Winner: RomiGameplays
# RomiGameplays (Paper) vs SnoopiFredo (Lizard) => Winner: SnoopiFredo
# Lukesize (Lizard) vs brunocerdan3 (Scissors) => Winner: brunocerdan3
# Lukesize (Rock) vs Jeni (Spock) => Winner: Jeni
# Lukesize (Spock) vs Annie (Paper) => Winner: Annie
# Lukesize (Rock) vs SnoopiFredo (Spock) => Winner: SnoopiFredo
# brunocerdan3 (Lizard) vs Jeni (Scissors) => Winner: Jeni
# brunocerdan3 (Paper) vs Annie (Scissors) => Winner: Annie
# brunocerdan3 (Lizard) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# Jeni (Rock) vs Annie (Spock) => Winner: Annie
# Jeni (Spock) vs SnoopiFredo (Spock) => Winner: Tie
# Annie (Lizard) vs SnoopiFredo (Rock) => Winner: SnoopiFredo
#
# Current Scores:
# Mword: 15 points
# Mari: 11 points
# CarlosGOD: 8 points
# Hisendo02: 12 points
# RomiGameplays: 17 points
# Lukesize: 15 points
# brunocerdan3: 16 points
# Jeni: 18 points
# Annie: 17 points
# SnoopiFredo: 15 points
#
#
# --- Round 5 ---
# Mword (Spock) vs Mari (Rock) => Winner: Mword
# Mword (Spock) vs CarlosGOD (Paper) => Winner: CarlosGOD
# Mword (Scissors) vs Hisendo02 (Lizard) => Winner: Mword
# Mword (Scissors) vs RomiGameplays (Scissors) => Winner: Tie
# Mword (Lizard) vs Lukesize (Spock) => Winner: Mword
# Mword (Spock) vs brunocerdan3 (Spock) => Winner: Tie
# Mword (Spock) vs Jeni (Lizard) => Winner: Jeni
# Mword (Spock) vs Annie (Lizard) => Winner: Annie
# Mword (Lizard) vs SnoopiFredo (Rock) => Winner: SnoopiFredo
# Mari (Rock) vs CarlosGOD (Lizard) => Winner: Mari
# Mari (Scissors) vs Hisendo02 (Paper) => Winner: Mari
# Mari (Lizard) vs RomiGameplays (Lizard) => Winner: Tie
# Mari (Rock) vs Lukesize (Lizard) => Winner: Mari
# Mari (Scissors) vs brunocerdan3 (Paper) => Winner: Mari
# Mari (Spock) vs Jeni (Spock) => Winner: Tie
# Mari (Rock) vs Annie (Paper) => Winner: Annie
# Mari (Scissors) vs SnoopiFredo (Rock) => Winner: SnoopiFredo
# CarlosGOD (Lizard) vs Hisendo02 (Spock) => Winner: CarlosGOD
# CarlosGOD (Scissors) vs RomiGameplays (Scissors) => Winner: Tie
# CarlosGOD (Scissors) vs Lukesize (Lizard) => Winner: CarlosGOD
# CarlosGOD (Scissors) vs brunocerdan3 (Rock) => Winner: brunocerdan3
# CarlosGOD (Scissors) vs Jeni (Rock) => Winner: Jeni
# CarlosGOD (Spock) vs Annie (Rock) => Winner: CarlosGOD
# CarlosGOD (Scissors) vs SnoopiFredo (Spock) => Winner: SnoopiFredo
# Hisendo02 (Rock) vs RomiGameplays (Spock) => Winner: RomiGameplays
# Hisendo02 (Spock) vs Lukesize (Lizard) => Winner: Lukesize
# Hisendo02 (Scissors) vs brunocerdan3 (Scissors) => Winner: Tie
# Hisendo02 (Paper) vs Jeni (Lizard) => Winner: Jeni
# Hisendo02 (Rock) vs Annie (Rock) => Winner: Tie
# Hisendo02 (Lizard) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# RomiGameplays (Scissors) vs Lukesize (Rock) => Winner: Lukesize
# RomiGameplays (Lizard) vs brunocerdan3 (Scissors) => Winner: brunocerdan3
# RomiGameplays (Paper) vs Jeni (Rock) => Winner: RomiGameplays
# RomiGameplays (Rock) vs Annie (Lizard) => Winner: RomiGameplays
# RomiGameplays (Scissors) vs SnoopiFredo (Lizard) => Winner: RomiGameplays
# Lukesize (Spock) vs brunocerdan3 (Spock) => Winner: Tie
# Lukesize (Spock) vs Jeni (Scissors) => Winner: Lukesize
# Lukesize (Paper) vs Annie (Spock) => Winner: Lukesize
# Lukesize (Spock) vs SnoopiFredo (Paper) => Winner: SnoopiFredo
# brunocerdan3 (Rock) vs Jeni (Lizard) => Winner: brunocerdan3
# brunocerdan3 (Paper) vs Annie (Lizard) => Winner: Annie
# brunocerdan3 (Rock) vs SnoopiFredo (Lizard) => Winner: brunocerdan3
# Jeni (Lizard) vs Annie (Rock) => Winner: Annie
# Jeni (Scissors) vs SnoopiFredo (Paper) => Winner: Jeni
# Annie (Scissors) vs SnoopiFredo (Paper) => Winner: Annie
#
# Current Scores:
# Mword: 18 points
# Mari: 15 points
# CarlosGOD: 12 points
# Hisendo02: 12 points
# RomiGameplays: 21 points
# Lukesize: 19 points
# brunocerdan3: 20 points
# Jeni: 22 points
# Annie: 22 points
# SnoopiFredo: 20 points
#
#
# --- Round 6 ---
# Mword (Rock) vs Mari (Scissors) => Winner: Mword
# Mword (Rock) vs CarlosGOD (Scissors) => Winner: Mword
# Mword (Spock) vs Hisendo02 (Rock) => Winner: Mword
# Mword (Scissors) vs RomiGameplays (Paper) => Winner: Mword
# Mword (Paper) vs Lukesize (Spock) => Winner: Mword
# Mword (Lizard) vs brunocerdan3 (Spock) => Winner: Mword
# Mword (Lizard) vs Jeni (Paper) => Winner: Mword
# Mword (Paper) vs Annie (Lizard) => Winner: Annie
# Mword (Paper) vs SnoopiFredo (Rock) => Winner: Mword
# Mari (Lizard) vs CarlosGOD (Spock) => Winner: Mari
# Mari (Scissors) vs Hisendo02 (Spock) => Winner: Hisendo02
# Mari (Paper) vs RomiGameplays (Spock) => Winner: Mari
# Mari (Scissors) vs Lukesize (Spock) => Winner: Lukesize
# Mari (Rock) vs brunocerdan3 (Spock) => Winner: brunocerdan3
# Mari (Paper) vs Jeni (Scissors) => Winner: Jeni
# Mari (Scissors) vs Annie (Rock) => Winner: Annie
# Mari (Scissors) vs SnoopiFredo (Rock) => Winner: SnoopiFredo
# CarlosGOD (Scissors) vs Hisendo02 (Lizard) => Winner: CarlosGOD
# CarlosGOD (Scissors) vs RomiGameplays (Scissors) => Winner: Tie
# CarlosGOD (Paper) vs Lukesize (Spock) => Winner: CarlosGOD
# CarlosGOD (Scissors) vs brunocerdan3 (Spock) => Winner: brunocerdan3
# CarlosGOD (Paper) vs Jeni (Rock) => Winner: CarlosGOD
# CarlosGOD (Paper) vs Annie (Paper) => Winner: Tie
# CarlosGOD (Paper) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# Hisendo02 (Paper) vs RomiGameplays (Rock) => Winner: Hisendo02
# Hisendo02 (Paper) vs Lukesize (Paper) => Winner: Tie
# Hisendo02 (Paper) vs brunocerdan3 (Paper) => Winner: Tie
# Hisendo02 (Rock) vs Jeni (Rock) => Winner: Tie
# Hisendo02 (Paper) vs Annie (Rock) => Winner: Hisendo02
# Hisendo02 (Rock) vs SnoopiFredo (Spock) => Winner: SnoopiFredo
# RomiGameplays (Spock) vs Lukesize (Paper) => Winner: Lukesize
# RomiGameplays (Spock) vs brunocerdan3 (Lizard) => Winner: brunocerdan3
# RomiGameplays (Scissors) vs Jeni (Lizard) => Winner: RomiGameplays
# RomiGameplays (Scissors) vs Annie (Rock) => Winner: Annie
# RomiGameplays (Rock) vs SnoopiFredo (Spock) => Winner: SnoopiFredo
# Lukesize (Scissors) vs brunocerdan3 (Scissors) => Winner: Tie
# Lukesize (Lizard) vs Jeni (Scissors) => Winner: Jeni
# Lukesize (Scissors) vs Annie (Rock) => Winner: Annie
# Lukesize (Spock) vs SnoopiFredo (Rock) => Winner: Lukesize
# brunocerdan3 (Lizard) vs Jeni (Scissors) => Winner: Jeni
# brunocerdan3 (Lizard) vs Annie (Scissors) => Winner: Annie
# brunocerdan3 (Paper) vs SnoopiFredo (Lizard) => Winner: SnoopiFredo
# Jeni (Lizard) vs Annie (Rock) => Winner: Annie
# Jeni (Lizard) vs SnoopiFredo (Rock) => Winner: SnoopiFredo
# Annie (Scissors) vs SnoopiFredo (Spock) => Winner: SnoopiFredo
#
# Current Scores:
# Mword: 26 points
# Mari: 17 points
# CarlosGOD: 15 points
# Hisendo02: 15 points
# RomiGameplays: 22 points
# Lukesize: 22 points
# brunocerdan3: 23 points
# Jeni: 25 points
# Annie: 28 points
# SnoopiFredo: 27 points
#
#
# --- Round 7 ---
# Mword (Paper) vs Mari (Lizard) => Winner: Mari
# Mword (Spock) vs CarlosGOD (Scissors) => Winner: Mword
# Mword (Scissors) vs Hisendo02 (Spock) => Winner: Hisendo02
# Mword (Lizard) vs RomiGameplays (Paper) => Winner: Mword
# Mword (Rock) vs Lukesize (Paper) => Winner: Lukesize
# Mword (Scissors) vs brunocerdan3 (Lizard) => Winner: Mword
# Mword (Spock) vs Jeni (Rock) => Winner: Mword
# Mword (Scissors) vs Annie (Lizard) => Winner: Mword
# Mword (Spock) vs SnoopiFredo (Scissors) => Winner: Mword
# Mari (Lizard) vs CarlosGOD (Lizard) => Winner: Tie
# Mari (Paper) vs Hisendo02 (Paper) => Winner: Tie
# Mari (Spock) vs RomiGameplays (Scissors) => Winner: Mari
# Mari (Scissors) vs Lukesize (Rock) => Winner: Lukesize
# Mari (Paper) vs brunocerdan3 (Scissors) => Winner: brunocerdan3
# Mari (Rock) vs Jeni (Rock) => Winner: Tie
# Mari (Rock) vs Annie (Rock) => Winner: Tie
# Mari (Spock) vs SnoopiFredo (Paper) => Winner: SnoopiFredo
# CarlosGOD (Rock) vs Hisendo02 (Lizard) => Winner: CarlosGOD
# CarlosGOD (Spock) vs RomiGameplays (Paper) => Winner: RomiGameplays
# CarlosGOD (Spock) vs Lukesize (Scissors) => Winner: CarlosGOD
# CarlosGOD (Spock) vs brunocerdan3 (Rock) => Winner: CarlosGOD
# CarlosGOD (Scissors) vs Jeni (Paper) => Winner: CarlosGOD
# CarlosGOD (Rock) vs Annie (Spock) => Winner: Annie
# CarlosGOD (Paper) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# Hisendo02 (Paper) vs RomiGameplays (Lizard) => Winner: RomiGameplays
# Hisendo02 (Scissors) vs Lukesize (Rock) => Winner: Lukesize
# Hisendo02 (Scissors) vs brunocerdan3 (Scissors) => Winner: Tie
# Hisendo02 (Lizard) vs Jeni (Scissors) => Winner: Jeni
# Hisendo02 (Scissors) vs Annie (Scissors) => Winner: Tie
# Hisendo02 (Lizard) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# RomiGameplays (Lizard) vs Lukesize (Lizard) => Winner: Tie
# RomiGameplays (Lizard) vs brunocerdan3 (Rock) => Winner: brunocerdan3
# RomiGameplays (Scissors) vs Jeni (Spock) => Winner: Jeni
# RomiGameplays (Lizard) vs Annie (Paper) => Winner: RomiGameplays
# RomiGameplays (Spock) vs SnoopiFredo (Paper) => Winner: SnoopiFredo
# Lukesize (Scissors) vs brunocerdan3 (Paper) => Winner: Lukesize
# Lukesize (Paper) vs Jeni (Lizard) => Winner: Jeni
# Lukesize (Spock) vs Annie (Scissors) => Winner: Lukesize
# Lukesize (Lizard) vs SnoopiFredo (Spock) => Winner: Lukesize
# brunocerdan3 (Lizard) vs Jeni (Paper) => Winner: brunocerdan3
# brunocerdan3 (Rock) vs Annie (Spock) => Winner: Annie
# brunocerdan3 (Rock) vs SnoopiFredo (Paper) => Winner: SnoopiFredo
# Jeni (Paper) vs Annie (Scissors) => Winner: Annie
# Jeni (Scissors) vs SnoopiFredo (Spock) => Winner: SnoopiFredo
# Annie (Scissors) vs SnoopiFredo (Paper) => Winner: Annie
#
# Current Scores:
# Mword: 32 points
# Mari: 19 points
# CarlosGOD: 19 points
# Hisendo02: 16 points
# RomiGameplays: 25 points
# Lukesize: 28 points
# brunocerdan3: 26 points
# Jeni: 28 points
# Annie: 32 points
# SnoopiFredo: 33 points
#
#
# --- Round 8 ---
# Mword (Lizard) vs Mari (Paper) => Winner: Mword
# Mword (Rock) vs CarlosGOD (Rock) => Winner: Tie
# Mword (Scissors) vs Hisendo02 (Spock) => Winner: Hisendo02
# Mword (Rock) vs RomiGameplays (Lizard) => Winner: Mword
# Mword (Spock) vs Lukesize (Paper) => Winner: Lukesize
# Mword (Lizard) vs brunocerdan3 (Rock) => Winner: brunocerdan3
# Mword (Rock) vs Jeni (Lizard) => Winner: Mword
# Mword (Spock) vs Annie (Scissors) => Winner: Mword
# Mword (Spock) vs SnoopiFredo (Spock) => Winner: Tie
# Mari (Rock) vs CarlosGOD (Lizard) => Winner: Mari
# Mari (Scissors) vs Hisendo02 (Lizard) => Winner: Mari
# Mari (Paper) vs RomiGameplays (Scissors) => Winner: RomiGameplays
# Mari (Rock) vs Lukesize (Spock) => Winner: Lukesize
# Mari (Paper) vs brunocerdan3 (Paper) => Winner: Tie
# Mari (Spock) vs Jeni (Rock) => Winner: Mari
# Mari (Spock) vs Annie (Scissors) => Winner: Mari
# Mari (Spock) vs SnoopiFredo (Scissors) => Winner: Mari
# CarlosGOD (Lizard) vs Hisendo02 (Paper) => Winner: CarlosGOD
# CarlosGOD (Lizard) vs RomiGameplays (Scissors) => Winner: RomiGameplays
# CarlosGOD (Paper) vs Lukesize (Rock) => Winner: CarlosGOD
# CarlosGOD (Lizard) vs brunocerdan3 (Lizard) => Winner: Tie
# CarlosGOD (Paper) vs Jeni (Lizard) => Winner: Jeni
# CarlosGOD (Lizard) vs Annie (Spock) => Winner: CarlosGOD
# CarlosGOD (Paper) vs SnoopiFredo (Rock) => Winner: CarlosGOD
# Hisendo02 (Spock) vs RomiGameplays (Spock) => Winner: Tie
# Hisendo02 (Paper) vs Lukesize (Paper) => Winner: Tie
# Hisendo02 (Rock) vs brunocerdan3 (Lizard) => Winner: Hisendo02
# Hisendo02 (Rock) vs Jeni (Rock) => Winner: Tie
# Hisendo02 (Paper) vs Annie (Lizard) => Winner: Annie
# Hisendo02 (Rock) vs SnoopiFredo (Lizard) => Winner: Hisendo02
# RomiGameplays (Rock) vs Lukesize (Lizard) => Winner: RomiGameplays
# RomiGameplays (Scissors) vs brunocerdan3 (Spock) => Winner: brunocerdan3
# RomiGameplays (Paper) vs Jeni (Paper) => Winner: Tie
# RomiGameplays (Scissors) vs Annie (Lizard) => Winner: RomiGameplays
# RomiGameplays (Rock) vs SnoopiFredo (Lizard) => Winner: RomiGameplays
# Lukesize (Spock) vs brunocerdan3 (Paper) => Winner: brunocerdan3
# Lukesize (Paper) vs Jeni (Rock) => Winner: Lukesize
# Lukesize (Spock) vs Annie (Spock) => Winner: Tie
# Lukesize (Spock) vs SnoopiFredo (Lizard) => Winner: SnoopiFredo
# brunocerdan3 (Paper) vs Jeni (Rock) => Winner: brunocerdan3
# brunocerdan3 (Lizard) vs Annie (Paper) => Winner: brunocerdan3
# brunocerdan3 (Paper) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# Jeni (Scissors) vs Annie (Paper) => Winner: Jeni
# Jeni (Rock) vs SnoopiFredo (Scissors) => Winner: Jeni
# Annie (Lizard) vs SnoopiFredo (Lizard) => Winner: Tie
#
# Current Scores:
# Mword: 36 points
# Mari: 24 points
# CarlosGOD: 23 points
# Hisendo02: 19 points
# RomiGameplays: 30 points
# Lukesize: 31 points
# brunocerdan3: 31 points
# Jeni: 31 points
# Annie: 33 points
# SnoopiFredo: 35 points
#
#
# --- Round 9 ---
# Mword (Paper) vs Mari (Rock) => Winner: Mword
# Mword (Paper) vs CarlosGOD (Spock) => Winner: Mword
# Mword (Paper) vs Hisendo02 (Spock) => Winner: Mword
# Mword (Paper) vs RomiGameplays (Paper) => Winner: Tie
# Mword (Paper) vs Lukesize (Lizard) => Winner: Lukesize
# Mword (Spock) vs brunocerdan3 (Scissors) => Winner: Mword
# Mword (Rock) vs Jeni (Spock) => Winner: Jeni
# Mword (Rock) vs Annie (Scissors) => Winner: Mword
# Mword (Paper) vs SnoopiFredo (Lizard) => Winner: SnoopiFredo
# Mari (Rock) vs CarlosGOD (Paper) => Winner: CarlosGOD
# Mari (Scissors) vs Hisendo02 (Paper) => Winner: Mari
# Mari (Spock) vs RomiGameplays (Scissors) => Winner: Mari
# Mari (Lizard) vs Lukesize (Spock) => Winner: Mari
# Mari (Scissors) vs brunocerdan3 (Scissors) => Winner: Tie
# Mari (Rock) vs Jeni (Scissors) => Winner: Mari
# Mari (Spock) vs Annie (Lizard) => Winner: Annie
# Mari (Paper) vs SnoopiFredo (Rock) => Winner: Mari
# CarlosGOD (Scissors) vs Hisendo02 (Paper) => Winner: CarlosGOD
# CarlosGOD (Scissors) vs RomiGameplays (Scissors) => Winner: Tie
# CarlosGOD (Paper) vs Lukesize (Lizard) => Winner: Lukesize
# CarlosGOD (Rock) vs brunocerdan3 (Rock) => Winner: Tie
# CarlosGOD (Lizard) vs Jeni (Rock) => Winner: Jeni
# CarlosGOD (Spock) vs Annie (Scissors) => Winner: CarlosGOD
# CarlosGOD (Paper) vs SnoopiFredo (Spock) => Winner: CarlosGOD
# Hisendo02 (Spock) vs RomiGameplays (Scissors) => Winner: Hisendo02
# Hisendo02 (Scissors) vs Lukesize (Spock) => Winner: Lukesize
# Hisendo02 (Paper) vs brunocerdan3 (Scissors) => Winner: brunocerdan3
# Hisendo02 (Paper) vs Jeni (Rock) => Winner: Hisendo02
# Hisendo02 (Lizard) vs Annie (Lizard) => Winner: Tie
# Hisendo02 (Scissors) vs SnoopiFredo (Paper) => Winner: Hisendo02
# RomiGameplays (Lizard) vs Lukesize (Rock) => Winner: Lukesize
# RomiGameplays (Spock) vs brunocerdan3 (Spock) => Winner: Tie
# RomiGameplays (Spock) vs Jeni (Lizard) => Winner: Jeni
# RomiGameplays (Spock) vs Annie (Rock) => Winner: RomiGameplays
# RomiGameplays (Scissors) vs SnoopiFredo (Paper) => Winner: RomiGameplays
# Lukesize (Scissors) vs brunocerdan3 (Rock) => Winner: brunocerdan3
# Lukesize (Paper) vs Jeni (Spock) => Winner: Lukesize
# Lukesize (Scissors) vs Annie (Paper) => Winner: Lukesize
# Lukesize (Scissors) vs SnoopiFredo (Lizard) => Winner: Lukesize
# brunocerdan3 (Paper) vs Jeni (Spock) => Winner: brunocerdan3
# brunocerdan3 (Lizard) vs Annie (Rock) => Winner: Annie
# brunocerdan3 (Rock) vs SnoopiFredo (Lizard) => Winner: brunocerdan3
# Jeni (Rock) vs Annie (Rock) => Winner: Tie
# Jeni (Paper) vs SnoopiFredo (Rock) => Winner: Jeni
# Annie (Scissors) vs SnoopiFredo (Spock) => Winner: SnoopiFredo
#
# Current Scores:
# Mword: 41 points
# Mari: 29 points
# CarlosGOD: 27 points
# Hisendo02: 22 points
# RomiGameplays: 32 points
# Lukesize: 38 points
# brunocerdan3: 35 points
# Jeni: 35 points
# Annie: 35 points
# SnoopiFredo: 37 points
#
#
# --- Round 10 ---
# Mword (Lizard) vs Mari (Scissors) => Winner: Mari
# Mword (Paper) vs CarlosGOD (Paper) => Winner: Tie
# Mword (Rock) vs Hisendo02 (Lizard) => Winner: Mword
# Mword (Scissors) vs RomiGameplays (Lizard) => Winner: Mword
# Mword (Lizard) vs Lukesize (Scissors) => Winner: Lukesize
# Mword (Paper) vs brunocerdan3 (Spock) => Winner: Mword
# Mword (Spock) vs Jeni (Scissors) => Winner: Mword
# Mword (Scissors) vs Annie (Scissors) => Winner: Tie
# Mword (Paper) vs SnoopiFredo (Lizard) => Winner: SnoopiFredo
# Mari (Lizard) vs CarlosGOD (Scissors) => Winner: CarlosGOD
# Mari (Rock) vs Hisendo02 (Scissors) => Winner: Mari
# Mari (Paper) vs RomiGameplays (Spock) => Winner: Mari
# Mari (Rock) vs Lukesize (Paper) => Winner: Lukesize
# Mari (Lizard) vs brunocerdan3 (Rock) => Winner: brunocerdan3
# Mari (Paper) vs Jeni (Rock) => Winner: Mari
# Mari (Scissors) vs Annie (Paper) => Winner: Mari
# Mari (Lizard) vs SnoopiFredo (Lizard) => Winner: Tie
# CarlosGOD (Scissors) vs Hisendo02 (Paper) => Winner: CarlosGOD
# CarlosGOD (Rock) vs RomiGameplays (Spock) => Winner: RomiGameplays
# CarlosGOD (Rock) vs Lukesize (Rock) => Winner: Tie
# CarlosGOD (Rock) vs brunocerdan3 (Lizard) => Winner: CarlosGOD
# CarlosGOD (Lizard) vs Jeni (Scissors) => Winner: Jeni
# CarlosGOD (Lizard) vs Annie (Spock) => Winner: CarlosGOD
# CarlosGOD (Scissors) vs SnoopiFredo (Lizard) => Winner: CarlosGOD
# Hisendo02 (Spock) vs RomiGameplays (Paper) => Winner: RomiGameplays
# Hisendo02 (Spock) vs Lukesize (Lizard) => Winner: Lukesize
# Hisendo02 (Spock) vs brunocerdan3 (Rock) => Winner: Hisendo02
# Hisendo02 (Lizard) vs Jeni (Scissors) => Winner: Jeni
# Hisendo02 (Paper) vs Annie (Scissors) => Winner: Annie
# Hisendo02 (Spock) vs SnoopiFredo (Scissors) => Winner: Hisendo02
# RomiGameplays (Spock) vs Lukesize (Rock) => Winner: RomiGameplays
# RomiGameplays (Rock) vs brunocerdan3 (Paper) => Winner: brunocerdan3
# RomiGameplays (Paper) vs Jeni (Scissors) => Winner: Jeni
# RomiGameplays (Scissors) vs Annie (Rock) => Winner: Annie
# RomiGameplays (Lizard) vs SnoopiFredo (Spock) => Winner: RomiGameplays
# Lukesize (Scissors) vs brunocerdan3 (Paper) => Winner: Lukesize
# Lukesize (Rock) vs Jeni (Rock) => Winner: Tie
# Lukesize (Paper) vs Annie (Spock) => Winner: Lukesize
# Lukesize (Scissors) vs SnoopiFredo (Spock) => Winner: SnoopiFredo
# brunocerdan3 (Lizard) vs Jeni (Lizard) => Winner: Tie
# brunocerdan3 (Spock) vs Annie (Scissors) => Winner: brunocerdan3
# brunocerdan3 (Paper) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# Jeni (Paper) vs Annie (Lizard) => Winner: Annie
# Jeni (Paper) vs SnoopiFredo (Lizard) => Winner: SnoopiFredo
# Annie (Scissors) vs SnoopiFredo (Rock) => Winner: SnoopiFredo
#
# Current Scores:
# Mword: 45 points
# Mari: 34 points
# CarlosGOD: 32 points
# Hisendo02: 24 points
# RomiGameplays: 36 points
# Lukesize: 43 points
# brunocerdan3: 38 points
# Jeni: 38 points
# Annie: 38 points
# SnoopiFredo: 42 points
#
#
# --- Round 11 ---
# Mword (Spock) vs Mari (Paper) => Winner: Mari
# Mword (Paper) vs CarlosGOD (Scissors) => Winner: CarlosGOD
# Mword (Paper) vs Hisendo02 (Spock) => Winner: Mword
# Mword (Rock) vs RomiGameplays (Paper) => Winner: RomiGameplays
# Mword (Scissors) vs Lukesize (Scissors) => Winner: Tie
# Mword (Paper) vs brunocerdan3 (Lizard) => Winner: brunocerdan3
# Mword (Rock) vs Jeni (Paper) => Winner: Jeni
# Mword (Scissors) vs Annie (Scissors) => Winner: Tie
# Mword (Lizard) vs SnoopiFredo (Spock) => Winner: Mword
# Mari (Spock) vs CarlosGOD (Rock) => Winner: Mari
# Mari (Spock) vs Hisendo02 (Paper) => Winner: Hisendo02
# Mari (Lizard) vs RomiGameplays (Lizard) => Winner: Tie
# Mari (Paper) vs Lukesize (Rock) => Winner: Mari
# Mari (Spock) vs brunocerdan3 (Paper) => Winner: brunocerdan3
# Mari (Rock) vs Jeni (Paper) => Winner: Jeni
# Mari (Rock) vs Annie (Paper) => Winner: Annie
# Mari (Spock) vs SnoopiFredo (Lizard) => Winner: SnoopiFredo
# CarlosGOD (Lizard) vs Hisendo02 (Spock) => Winner: CarlosGOD
# CarlosGOD (Paper) vs RomiGameplays (Lizard) => Winner: RomiGameplays
# CarlosGOD (Paper) vs Lukesize (Paper) => Winner: Tie
# CarlosGOD (Scissors) vs brunocerdan3 (Spock) => Winner: brunocerdan3
# CarlosGOD (Paper) vs Jeni (Scissors) => Winner: Jeni
# CarlosGOD (Spock) vs Annie (Spock) => Winner: Tie
# CarlosGOD (Rock) vs SnoopiFredo (Paper) => Winner: SnoopiFredo
# Hisendo02 (Scissors) vs RomiGameplays (Paper) => Winner: Hisendo02
# Hisendo02 (Scissors) vs Lukesize (Rock) => Winner: Lukesize
# Hisendo02 (Lizard) vs brunocerdan3 (Scissors) => Winner: brunocerdan3
# Hisendo02 (Rock) vs Jeni (Rock) => Winner: Tie
# Hisendo02 (Rock) vs Annie (Spock) => Winner: Annie
# Hisendo02 (Lizard) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# RomiGameplays (Scissors) vs Lukesize (Rock) => Winner: Lukesize
# RomiGameplays (Scissors) vs brunocerdan3 (Spock) => Winner: brunocerdan3
# RomiGameplays (Rock) vs Jeni (Lizard) => Winner: RomiGameplays
# RomiGameplays (Rock) vs Annie (Paper) => Winner: Annie
# RomiGameplays (Scissors) vs SnoopiFredo (Scissors) => Winner: Tie
# Lukesize (Spock) vs brunocerdan3 (Spock) => Winner: Tie
# Lukesize (Lizard) vs Jeni (Spock) => Winner: Lukesize
# Lukesize (Lizard) vs Annie (Spock) => Winner: Lukesize
# Lukesize (Paper) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# brunocerdan3 (Spock) vs Jeni (Lizard) => Winner: Jeni
# brunocerdan3 (Lizard) vs Annie (Paper) => Winner: brunocerdan3
# brunocerdan3 (Spock) vs SnoopiFredo (Scissors) => Winner: brunocerdan3
# Jeni (Rock) vs Annie (Paper) => Winner: Annie
# Jeni (Lizard) vs SnoopiFredo (Spock) => Winner: Jeni
# Annie (Paper) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
#
# Current Scores:
# Mword: 47 points
# Mari: 37 points
# CarlosGOD: 34 points
# Hisendo02: 26 points
# RomiGameplays: 39 points
# Lukesize: 47 points
# brunocerdan3: 45 points
# Jeni: 43 points
# Annie: 42 points
# SnoopiFredo: 47 points
#
#
# --- Round 12 ---
# Mword (Scissors) vs Mari (Spock) => Winner: Mari
# Mword (Spock) vs CarlosGOD (Paper) => Winner: CarlosGOD
# Mword (Scissors) vs Hisendo02 (Spock) => Winner: Hisendo02
# Mword (Rock) vs RomiGameplays (Paper) => Winner: RomiGameplays
# Mword (Rock) vs Lukesize (Rock) => Winner: Tie
# Mword (Spock) vs brunocerdan3 (Lizard) => Winner: brunocerdan3
# Mword (Paper) vs Jeni (Paper) => Winner: Tie
# Mword (Scissors) vs Annie (Lizard) => Winner: Mword
# Mword (Spock) vs SnoopiFredo (Rock) => Winner: Mword
# Mari (Rock) vs CarlosGOD (Scissors) => Winner: Mari
# Mari (Rock) vs Hisendo02 (Rock) => Winner: Tie
# Mari (Lizard) vs RomiGameplays (Lizard) => Winner: Tie
# Mari (Lizard) vs Lukesize (Rock) => Winner: Lukesize
# Mari (Scissors) vs brunocerdan3 (Rock) => Winner: brunocerdan3
# Mari (Spock) vs Jeni (Rock) => Winner: Mari
# Mari (Rock) vs Annie (Rock) => Winner: Tie
# Mari (Rock) vs SnoopiFredo (Rock) => Winner: Tie
# CarlosGOD (Paper) vs Hisendo02 (Scissors) => Winner: Hisendo02
# CarlosGOD (Rock) vs RomiGameplays (Scissors) => Winner: CarlosGOD
# CarlosGOD (Scissors) vs Lukesize (Scissors) => Winner: Tie
# CarlosGOD (Scissors) vs brunocerdan3 (Lizard) => Winner: CarlosGOD
# CarlosGOD (Rock) vs Jeni (Scissors) => Winner: CarlosGOD
# CarlosGOD (Paper) vs Annie (Lizard) => Winner: Annie
# CarlosGOD (Paper) vs SnoopiFredo (Paper) => Winner: Tie
# Hisendo02 (Rock) vs RomiGameplays (Spock) => Winner: RomiGameplays
# Hisendo02 (Lizard) vs Lukesize (Paper) => Winner: Hisendo02
# Hisendo02 (Scissors) vs brunocerdan3 (Rock) => Winner: brunocerdan3
# Hisendo02 (Paper) vs Jeni (Lizard) => Winner: Jeni
# Hisendo02 (Rock) vs Annie (Lizard) => Winner: Hisendo02
# Hisendo02 (Paper) vs SnoopiFredo (Lizard) => Winner: SnoopiFredo
# RomiGameplays (Rock) vs Lukesize (Lizard) => Winner: RomiGameplays
# RomiGameplays (Scissors) vs brunocerdan3 (Spock) => Winner: brunocerdan3
# RomiGameplays (Scissors) vs Jeni (Rock) => Winner: Jeni
# RomiGameplays (Lizard) vs Annie (Scissors) => Winner: Annie
# RomiGameplays (Paper) vs SnoopiFredo (Paper) => Winner: Tie
# Lukesize (Scissors) vs brunocerdan3 (Lizard) => Winner: Lukesize
# Lukesize (Paper) vs Jeni (Lizard) => Winner: Jeni
# Lukesize (Rock) vs Annie (Paper) => Winner: Annie
# Lukesize (Spock) vs SnoopiFredo (Lizard) => Winner: SnoopiFredo
# brunocerdan3 (Rock) vs Jeni (Rock) => Winner: Tie
# brunocerdan3 (Rock) vs Annie (Scissors) => Winner: brunocerdan3
# brunocerdan3 (Lizard) vs SnoopiFredo (Paper) => Winner: brunocerdan3
# Jeni (Lizard) vs Annie (Paper) => Winner: Jeni
# Jeni (Paper) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# Annie (Scissors) vs SnoopiFredo (Spock) => Winner: SnoopiFredo
#
# Current Scores:
# Mword: 49 points
# Mari: 40 points
# CarlosGOD: 38 points
# Hisendo02: 30 points
# RomiGameplays: 42 points
# Lukesize: 49 points
# brunocerdan3: 51 points
# Jeni: 47 points
# Annie: 45 points
# SnoopiFredo: 51 points
#
#
# --- Round 13 ---
# Mword (Spock) vs Mari (Rock) => Winner: Mword
# Mword (Paper) vs CarlosGOD (Rock) => Winner: Mword
# Mword (Rock) vs Hisendo02 (Spock) => Winner: Hisendo02
# Mword (Lizard) vs RomiGameplays (Rock) => Winner: RomiGameplays
# Mword (Lizard) vs Lukesize (Rock) => Winner: Lukesize
# Mword (Scissors) vs brunocerdan3 (Rock) => Winner: brunocerdan3
# Mword (Spock) vs Jeni (Scissors) => Winner: Mword
# Mword (Paper) vs Annie (Spock) => Winner: Mword
# Mword (Spock) vs SnoopiFredo (Paper) => Winner: SnoopiFredo
# Mari (Scissors) vs CarlosGOD (Lizard) => Winner: Mari
# Mari (Spock) vs Hisendo02 (Rock) => Winner: Mari
# Mari (Lizard) vs RomiGameplays (Lizard) => Winner: Tie
# Mari (Paper) vs Lukesize (Spock) => Winner: Mari
# Mari (Lizard) vs brunocerdan3 (Rock) => Winner: brunocerdan3
# Mari (Lizard) vs Jeni (Lizard) => Winner: Tie
# Mari (Spock) vs Annie (Paper) => Winner: Annie
# Mari (Rock) vs SnoopiFredo (Paper) => Winner: SnoopiFredo
# CarlosGOD (Paper) vs Hisendo02 (Lizard) => Winner: Hisendo02
# CarlosGOD (Rock) vs RomiGameplays (Spock) => Winner: RomiGameplays
# CarlosGOD (Lizard) vs Lukesize (Scissors) => Winner: Lukesize
# CarlosGOD (Scissors) vs brunocerdan3 (Rock) => Winner: brunocerdan3
# CarlosGOD (Lizard) vs Jeni (Rock) => Winner: Jeni
# CarlosGOD (Scissors) vs Annie (Spock) => Winner: Annie
# CarlosGOD (Paper) vs SnoopiFredo (Lizard) => Winner: SnoopiFredo
# Hisendo02 (Paper) vs RomiGameplays (Lizard) => Winner: RomiGameplays
# Hisendo02 (Lizard) vs Lukesize (Spock) => Winner: Hisendo02
# Hisendo02 (Lizard) vs brunocerdan3 (Scissors) => Winner: brunocerdan3
# Hisendo02 (Paper) vs Jeni (Paper) => Winner: Tie
# Hisendo02 (Paper) vs Annie (Rock) => Winner: Hisendo02
# Hisendo02 (Scissors) vs SnoopiFredo (Rock) => Winner: SnoopiFredo
# RomiGameplays (Spock) vs Lukesize (Paper) => Winner: Lukesize
# RomiGameplays (Spock) vs brunocerdan3 (Spock) => Winner: Tie
# RomiGameplays (Paper) vs Jeni (Scissors) => Winner: Jeni
# RomiGameplays (Rock) vs Annie (Scissors) => Winner: RomiGameplays
# RomiGameplays (Scissors) vs SnoopiFredo (Scissors) => Winner: Tie
# Lukesize (Spock) vs brunocerdan3 (Scissors) => Winner: Lukesize
# Lukesize (Lizard) vs Jeni (Scissors) => Winner: Jeni
# Lukesize (Lizard) vs Annie (Spock) => Winner: Lukesize
# Lukesize (Lizard) vs SnoopiFredo (Lizard) => Winner: Tie
# brunocerdan3 (Paper) vs Jeni (Scissors) => Winner: Jeni
# brunocerdan3 (Paper) vs Annie (Paper) => Winner: Tie
# brunocerdan3 (Scissors) vs SnoopiFredo (Paper) => Winner: brunocerdan3
# Jeni (Scissors) vs Annie (Rock) => Winner: Annie
# Jeni (Lizard) vs SnoopiFredo (Lizard) => Winner: Tie
# Annie (Paper) vs SnoopiFredo (Rock) => Winner: Annie
#
# Current Scores:
# Mword: 53 points
# Mari: 43 points
# CarlosGOD: 38 points
# Hisendo02: 34 points
# RomiGameplays: 46 points
# Lukesize: 54 points
# brunocerdan3: 56 points
# Jeni: 51 points
# Annie: 49 points
# SnoopiFredo: 55 points
#
#
# --- Round 14 ---
# Mword (Spock) vs Mari (Scissors) => Winner: Mword
# Mword (Rock) vs CarlosGOD (Spock) => Winner: CarlosGOD
# Mword (Lizard) vs Hisendo02 (Lizard) => Winner: Tie
# Mword (Lizard) vs RomiGameplays (Scissors) => Winner: RomiGameplays
# Mword (Scissors) vs Lukesize (Lizard) => Winner: Mword
# Mword (Spock) vs brunocerdan3 (Spock) => Winner: Tie
# Mword (Scissors) vs Jeni (Scissors) => Winner: Tie
# Mword (Spock) vs Annie (Lizard) => Winner: Annie
# Mword (Spock) vs SnoopiFredo (Spock) => Winner: Tie
# Mari (Rock) vs CarlosGOD (Lizard) => Winner: Mari
# Mari (Lizard) vs Hisendo02 (Spock) => Winner: Mari
# Mari (Spock) vs RomiGameplays (Spock) => Winner: Tie
# Mari (Rock) vs Lukesize (Rock) => Winner: Tie
# Mari (Rock) vs brunocerdan3 (Lizard) => Winner: Mari
# Mari (Paper) vs Jeni (Paper) => Winner: Tie
# Mari (Paper) vs Annie (Paper) => Winner: Tie
# Mari (Lizard) vs SnoopiFredo (Paper) => Winner: Mari
# CarlosGOD (Scissors) vs Hisendo02 (Rock) => Winner: Hisendo02
# CarlosGOD (Paper) vs RomiGameplays (Lizard) => Winner: RomiGameplays
# CarlosGOD (Paper) vs Lukesize (Spock) => Winner: CarlosGOD
# CarlosGOD (Spock) vs brunocerdan3 (Scissors) => Winner: CarlosGOD
# CarlosGOD (Paper) vs Jeni (Rock) => Winner: CarlosGOD
# CarlosGOD (Paper) vs Annie (Spock) => Winner: CarlosGOD
# CarlosGOD (Lizard) vs SnoopiFredo (Paper) => Winner: CarlosGOD
# Hisendo02 (Rock) vs RomiGameplays (Spock) => Winner: RomiGameplays
# Hisendo02 (Paper) vs Lukesize (Lizard) => Winner: Lukesize
# Hisendo02 (Paper) vs brunocerdan3 (Lizard) => Winner: brunocerdan3
# Hisendo02 (Spock) vs Jeni (Rock) => Winner: Hisendo02
# Hisendo02 (Lizard) vs Annie (Scissors) => Winner: Annie
# Hisendo02 (Lizard) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# RomiGameplays (Paper) vs Lukesize (Spock) => Winner: RomiGameplays
# RomiGameplays (Spock) vs brunocerdan3 (Lizard) => Winner: brunocerdan3
# RomiGameplays (Lizard) vs Jeni (Scissors) => Winner: Jeni
# RomiGameplays (Spock) vs Annie (Lizard) => Winner: Annie
# RomiGameplays (Rock) vs SnoopiFredo (Scissors) => Winner: RomiGameplays
# Lukesize (Scissors) vs brunocerdan3 (Paper) => Winner: Lukesize
# Lukesize (Paper) vs Jeni (Paper) => Winner: Tie
# Lukesize (Paper) vs Annie (Paper) => Winner: Tie
# Lukesize (Spock) vs SnoopiFredo (Paper) => Winner: SnoopiFredo
# brunocerdan3 (Rock) vs Jeni (Paper) => Winner: Jeni
# brunocerdan3 (Lizard) vs Annie (Scissors) => Winner: Annie
# brunocerdan3 (Spock) vs SnoopiFredo (Rock) => Winner: brunocerdan3
# Jeni (Rock) vs Annie (Spock) => Winner: Annie
# Jeni (Lizard) vs SnoopiFredo (Paper) => Winner: Jeni
# Annie (Scissors) vs SnoopiFredo (Scissors) => Winner: Tie
#
# Current Scores:
# Mword: 55 points
# Mari: 47 points
# CarlosGOD: 44 points
# Hisendo02: 36 points
# RomiGameplays: 51 points
# Lukesize: 56 points
# brunocerdan3: 59 points
# Jeni: 54 points
# Annie: 54 points
# SnoopiFredo: 57 points
#
#
# --- Round 15 ---
# Mword (Spock) vs Mari (Scissors) => Winner: Mword
# Mword (Rock) vs CarlosGOD (Lizard) => Winner: Mword
# Mword (Rock) vs Hisendo02 (Spock) => Winner: Hisendo02
# Mword (Scissors) vs RomiGameplays (Paper) => Winner: Mword
# Mword (Lizard) vs Lukesize (Rock) => Winner: Lukesize
# Mword (Scissors) vs brunocerdan3 (Lizard) => Winner: Mword
# Mword (Scissors) vs Jeni (Rock) => Winner: Jeni
# Mword (Rock) vs Annie (Rock) => Winner: Tie
# Mword (Lizard) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# Mari (Paper) vs CarlosGOD (Scissors) => Winner: CarlosGOD
# Mari (Rock) vs Hisendo02 (Rock) => Winner: Tie
# Mari (Lizard) vs RomiGameplays (Scissors) => Winner: RomiGameplays
# Mari (Scissors) vs Lukesize (Paper) => Winner: Mari
# Mari (Rock) vs brunocerdan3 (Spock) => Winner: brunocerdan3
# Mari (Paper) vs Jeni (Lizard) => Winner: Jeni
# Mari (Scissors) vs Annie (Paper) => Winner: Mari
# Mari (Scissors) vs SnoopiFredo (Paper) => Winner: Mari
# CarlosGOD (Spock) vs Hisendo02 (Paper) => Winner: Hisendo02
# CarlosGOD (Paper) vs RomiGameplays (Rock) => Winner: CarlosGOD
# CarlosGOD (Spock) vs Lukesize (Paper) => Winner: Lukesize
# CarlosGOD (Lizard) vs brunocerdan3 (Scissors) => Winner: brunocerdan3
# CarlosGOD (Rock) vs Jeni (Rock) => Winner: Tie
# CarlosGOD (Rock) vs Annie (Spock) => Winner: Annie
# CarlosGOD (Spock) vs SnoopiFredo (Lizard) => Winner: SnoopiFredo
# Hisendo02 (Spock) vs RomiGameplays (Scissors) => Winner: Hisendo02
# Hisendo02 (Lizard) vs Lukesize (Spock) => Winner: Hisendo02
# Hisendo02 (Rock) vs brunocerdan3 (Scissors) => Winner: Hisendo02
# Hisendo02 (Rock) vs Jeni (Spock) => Winner: Jeni
# Hisendo02 (Lizard) vs Annie (Lizard) => Winner: Tie
# Hisendo02 (Paper) vs SnoopiFredo (Lizard) => Winner: SnoopiFredo
# RomiGameplays (Lizard) vs Lukesize (Rock) => Winner: Lukesize
# RomiGameplays (Paper) vs brunocerdan3 (Spock) => Winner: RomiGameplays
# RomiGameplays (Paper) vs Jeni (Spock) => Winner: RomiGameplays
# RomiGameplays (Spock) vs Annie (Lizard) => Winner: Annie
# RomiGameplays (Lizard) vs SnoopiFredo (Rock) => Winner: SnoopiFredo
# Lukesize (Rock) vs brunocerdan3 (Paper) => Winner: brunocerdan3
# Lukesize (Lizard) vs Jeni (Scissors) => Winner: Jeni
# Lukesize (Paper) vs Annie (Lizard) => Winner: Annie
# Lukesize (Rock) vs SnoopiFredo (Spock) => Winner: SnoopiFredo
# brunocerdan3 (Paper) vs Jeni (Lizard) => Winner: Jeni
# brunocerdan3 (Lizard) vs Annie (Spock) => Winner: brunocerdan3
# brunocerdan3 (Spock) vs SnoopiFredo (Spock) => Winner: Tie
# Jeni (Lizard) vs Annie (Spock) => Winner: Jeni
# Jeni (Lizard) vs SnoopiFredo (Spock) => Winner: Jeni
# Annie (Rock) vs SnoopiFredo (Paper) => Winner: SnoopiFredo
#
# Current Scores:
# Mword: 59 points
# Mari: 50 points
# CarlosGOD: 46 points
# Hisendo02: 41 points
# RomiGameplays: 54 points
# Lukesize: 59 points
# brunocerdan3: 63 points
# Jeni: 61 points
# Annie: 57 points
# SnoopiFredo: 63 points
#
#
# --- Round 16 ---
# Mword (Spock) vs Mari (Rock) => Winner: Mword
# Mword (Scissors) vs CarlosGOD (Lizard) => Winner: Mword
# Mword (Spock) vs Hisendo02 (Spock) => Winner: Tie
# Mword (Paper) vs RomiGameplays (Spock) => Winner: Mword
# Mword (Scissors) vs Lukesize (Paper) => Winner: Mword
# Mword (Lizard) vs brunocerdan3 (Spock) => Winner: Mword
# Mword (Spock) vs Jeni (Rock) => Winner: Mword
# Mword (Lizard) vs Annie (Spock) => Winner: Mword
# Mword (Paper) vs SnoopiFredo (Lizard) => Winner: SnoopiFredo
# Mari (Paper) vs CarlosGOD (Paper) => Winner: Tie
# Mari (Scissors) vs Hisendo02 (Spock) => Winner: Hisendo02
# Mari (Spock) vs RomiGameplays (Paper) => Winner: RomiGameplays
# Mari (Scissors) vs Lukesize (Paper) => Winner: Mari
# Mari (Scissors) vs brunocerdan3 (Paper) => Winner: Mari
# Mari (Spock) vs Jeni (Scissors) => Winner: Mari
# Mari (Scissors) vs Annie (Lizard) => Winner: Mari
# Mari (Scissors) vs SnoopiFredo (Lizard) => Winner: Mari
# CarlosGOD (Lizard) vs Hisendo02 (Scissors) => Winner: Hisendo02
# CarlosGOD (Paper) vs RomiGameplays (Rock) => Winner: CarlosGOD
# CarlosGOD (Lizard) vs Lukesize (Lizard) => Winner: Tie
# CarlosGOD (Spock) vs brunocerdan3 (Rock) => Winner: CarlosGOD
# CarlosGOD (Paper) vs Jeni (Spock) => Winner: CarlosGOD
# CarlosGOD (Spock) vs Annie (Lizard) => Winner: Annie
# CarlosGOD (Rock) vs SnoopiFredo (Rock) => Winner: Tie
# Hisendo02 (Spock) vs RomiGameplays (Scissors) => Winner: Hisendo02
# Hisendo02 (Paper) vs Lukesize (Scissors) => Winner: Lukesize
# Hisendo02 (Spock) vs brunocerdan3 (Paper) => Winner: brunocerdan3
# Hisendo02 (Scissors) vs Jeni (Scissors) => Winner: Tie
# Hisendo02 (Lizard) vs Annie (Rock) => Winner: Annie
# Hisendo02 (Rock) vs SnoopiFredo (Lizard) => Winner: Hisendo02
# RomiGameplays (Scissors) vs Lukesize (Spock) => Winner: Lukesize
# RomiGameplays (Paper) vs brunocerdan3 (Spock) => Winner: RomiGameplays
# RomiGameplays (Lizard) vs Jeni (Rock) => Winner: Jeni
# RomiGameplays (Lizard) vs Annie (Paper) => Winner: RomiGameplays
# RomiGameplays (Rock) vs SnoopiFredo (Lizard) => Winner: RomiGameplays
# Lukesize (Paper) vs brunocerdan3 (Lizard) => Winner: brunocerdan3
# Lukesize (Paper) vs Jeni (Paper) => Winner: Tie
# Lukesize (Spock) vs Annie (Rock) => Winner: Lukesize
# Lukesize (Scissors) vs SnoopiFredo (Spock) => Winner: SnoopiFredo
# brunocerdan3 (Spock) vs Jeni (Spock) => Winner: Tie
# brunocerdan3 (Rock) vs Annie (Rock) => Winner: Tie
# brunocerdan3 (Spock) vs SnoopiFredo (Paper) => Winner: SnoopiFredo
# Jeni (Rock) vs Annie (Lizard) => Winner: Jeni
# Jeni (Paper) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# Annie (Rock) vs SnoopiFredo (Paper) => Winner: SnoopiFredo
#
# Current Scores:
# Mword: 66 points
# Mari: 55 points
# CarlosGOD: 49 points
# Hisendo02: 45 points
# RomiGameplays: 58 points
# Lukesize: 62 points
# brunocerdan3: 65 points
# Jeni: 63 points
# Annie: 59 points
# SnoopiFredo: 68 points
#
#
# --- Round 17 ---
# Mword (Rock) vs Mari (Scissors) => Winner: Mword
# Mword (Rock) vs CarlosGOD (Rock) => Winner: Tie
# Mword (Rock) vs Hisendo02 (Paper) => Winner: Hisendo02
# Mword (Rock) vs RomiGameplays (Rock) => Winner: Tie
# Mword (Spock) vs Lukesize (Scissors) => Winner: Mword
# Mword (Paper) vs brunocerdan3 (Lizard) => Winner: brunocerdan3
# Mword (Scissors) vs Jeni (Rock) => Winner: Jeni
# Mword (Scissors) vs Annie (Lizard) => Winner: Mword
# Mword (Lizard) vs SnoopiFredo (Paper) => Winner: Mword
# Mari (Spock) vs CarlosGOD (Rock) => Winner: Mari
# Mari (Rock) vs Hisendo02 (Paper) => Winner: Hisendo02
# Mari (Lizard) vs RomiGameplays (Rock) => Winner: RomiGameplays
# Mari (Spock) vs Lukesize (Rock) => Winner: Mari
# Mari (Rock) vs brunocerdan3 (Scissors) => Winner: Mari
# Mari (Paper) vs Jeni (Rock) => Winner: Mari
# Mari (Spock) vs Annie (Spock) => Winner: Tie
# Mari (Rock) vs SnoopiFredo (Lizard) => Winner: Mari
# CarlosGOD (Lizard) vs Hisendo02 (Spock) => Winner: CarlosGOD
# CarlosGOD (Paper) vs RomiGameplays (Spock) => Winner: CarlosGOD
# CarlosGOD (Rock) vs Lukesize (Spock) => Winner: Lukesize
# CarlosGOD (Paper) vs brunocerdan3 (Paper) => Winner: Tie
# CarlosGOD (Rock) vs Jeni (Rock) => Winner: Tie
# CarlosGOD (Lizard) vs Annie (Scissors) => Winner: Annie
# CarlosGOD (Paper) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# Hisendo02 (Lizard) vs RomiGameplays (Paper) => Winner: Hisendo02
# Hisendo02 (Paper) vs Lukesize (Lizard) => Winner: Lukesize
# Hisendo02 (Rock) vs brunocerdan3 (Scissors) => Winner: Hisendo02
# Hisendo02 (Scissors) vs Jeni (Lizard) => Winner: Hisendo02
# Hisendo02 (Rock) vs Annie (Rock) => Winner: Tie
# Hisendo02 (Scissors) vs SnoopiFredo (Spock) => Winner: SnoopiFredo
# RomiGameplays (Scissors) vs Lukesize (Spock) => Winner: Lukesize
# RomiGameplays (Paper) vs brunocerdan3 (Paper) => Winner: Tie
# RomiGameplays (Scissors) vs Jeni (Scissors) => Winner: Tie
# RomiGameplays (Lizard) vs Annie (Scissors) => Winner: Annie
# RomiGameplays (Lizard) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# Lukesize (Scissors) vs brunocerdan3 (Spock) => Winner: brunocerdan3
# Lukesize (Spock) vs Jeni (Scissors) => Winner: Lukesize
# Lukesize (Spock) vs Annie (Spock) => Winner: Tie
# Lukesize (Lizard) vs SnoopiFredo (Lizard) => Winner: Tie
# brunocerdan3 (Lizard) vs Jeni (Lizard) => Winner: Tie
# brunocerdan3 (Paper) vs Annie (Lizard) => Winner: Annie
# brunocerdan3 (Lizard) vs SnoopiFredo (Rock) => Winner: SnoopiFredo
# Jeni (Spock) vs Annie (Spock) => Winner: Tie
# Jeni (Lizard) vs SnoopiFredo (Paper) => Winner: Jeni
# Annie (Scissors) vs SnoopiFredo (Rock) => Winner: SnoopiFredo
#
# Current Scores:
# Mword: 70 points
# Mari: 60 points
# CarlosGOD: 51 points
# Hisendo02: 50 points
# RomiGameplays: 59 points
# Lukesize: 66 points
# brunocerdan3: 67 points
# Jeni: 65 points
# Annie: 62 points
# SnoopiFredo: 73 points
#
#
# --- Round 18 ---
# Mword (Lizard) vs Mari (Scissors) => Winner: Mari
# Mword (Lizard) vs CarlosGOD (Paper) => Winner: Mword
# ...
# Hisendo02 (Spock) vs RomiGameplays (Spock) => Winner: Tie
# Hisendo02 (Spock) vs Lukesize (Lizard) => Winner: Lukesize
# Hisendo02 (Lizard) vs brunocerdan3 (Paper) => Winner: Hisendo02
# Hisendo02 (Lizard) vs Jeni (Lizard) => Winner: Tie
# Hisendo02 (Rock) vs Annie (Lizard) => Winner: Hisendo02
# Hisendo02 (Scissors) vs SnoopiFredo (Scissors) => Winner: Tie
# RomiGameplays (Spock) vs Lukesize (Rock) => Winner: RomiGameplays
# RomiGameplays (Lizard) vs brunocerdan3 (Rock) => Winner: brunocerdan3
# RomiGameplays (Spock) vs Jeni (Lizard) => Winner: Jeni
# RomiGameplays (Rock) vs Annie (Scissors) => Winner: RomiGameplays
# RomiGameplays (Paper) vs SnoopiFredo (Spock) => Winner: RomiGameplays
# Lukesize (Spock) vs brunocerdan3 (Paper) => Winner: brunocerdan3
# Lukesize (Spock) vs Jeni (Scissors) => Winner: Lukesize
# Lukesize (Rock) vs Annie (Paper) => Winner: Annie
# Lukesize (Rock) vs SnoopiFredo (Lizard) => Winner: Lukesize
# brunocerdan3 (Rock) vs Jeni (Lizard) => Winner: brunocerdan3
# brunocerdan3 (Lizard) vs Annie (Lizard) => Winner: Tie
# brunocerdan3 (Spock) vs SnoopiFredo (Lizard) => Winner: SnoopiFredo
# Jeni (Scissors) vs Annie (Rock) => Winner: Annie
# Jeni (Scissors) vs SnoopiFredo (Paper) => Winner: Jeni
# Annie (Rock) vs SnoopiFredo (Rock) => Winner: Tie
#
# Current Scores:
# Mword: 350 points
# Mari: 344 points
# CarlosGOD: 337 points
# Hisendo02: 329 points
# RomiGameplays: 335 points
# Lukesize: 360 points
# brunocerdan3: 349 points
# Jeni: 354 points
# Annie: 336 points
# SnoopiFredo: 348 points
#
#
# --- Round 96 ---
# Mword (Rock) vs Mari (Spock) => Winner: Mari
# Mword (Rock) vs CarlosGOD (Rock) => Winner: Tie
# Mword (Paper) vs Hisendo02 (Spock) => Winner: Mword
# Mword (Spock) vs RomiGameplays (Rock) => Winner: Mword
# Mword (Paper) vs Lukesize (Scissors) => Winner: Lukesize
# Mword (Rock) vs brunocerdan3 (Scissors) => Winner: Mword
# Mword (Spock) vs Jeni (Spock) => Winner: Tie
# Mword (Paper) vs Annie (Scissors) => Winner: Annie
# Mword (Paper) vs SnoopiFredo (Spock) => Winner: Mword
# Mari (Spock) vs CarlosGOD (Paper) => Winner: CarlosGOD
# Mari (Lizard) vs Hisendo02 (Spock) => Winner: Mari
# Mari (Lizard) vs RomiGameplays (Paper) => Winner: Mari
# Mari (Scissors) vs Lukesize (Lizard) => Winner: Mari
# Mari (Rock) vs brunocerdan3 (Lizard) => Winner: Mari
# Mari (Scissors) vs Jeni (Spock) => Winner: Jeni
# Mari (Spock) vs Annie (Scissors) => Winner: Mari
# Mari (Lizard) vs SnoopiFredo (Spock) => Winner: Mari
# CarlosGOD (Rock) vs Hisendo02 (Rock) => Winner: Tie
# CarlosGOD (Rock) vs RomiGameplays (Scissors) => Winner: CarlosGOD
# CarlosGOD (Spock) vs Lukesize (Rock) => Winner: CarlosGOD
# CarlosGOD (Lizard) vs brunocerdan3 (Scissors) => Winner: brunocerdan3
# CarlosGOD (Paper) vs Jeni (Scissors) => Winner: Jeni
# CarlosGOD (Rock) vs Annie (Spock) => Winner: Annie
# CarlosGOD (Paper) vs SnoopiFredo (Rock) => Winner: CarlosGOD
# Hisendo02 (Rock) vs RomiGameplays (Spock) => Winner: RomiGameplays
# Hisendo02 (Scissors) vs Lukesize (Spock) => Winner: Lukesize
# Hisendo02 (Scissors) vs brunocerdan3 (Rock) => Winner: brunocerdan3
# Hisendo02 (Scissors) vs Jeni (Spock) => Winner: Jeni
# Hisendo02 (Paper) vs Annie (Paper) => Winner: Tie
# Hisendo02 (Spock) vs SnoopiFredo (Scissors) => Winner: Hisendo02
# RomiGameplays (Rock) vs Lukesize (Rock) => Winner: Tie
# RomiGameplays (Paper) vs brunocerdan3 (Lizard) => Winner: brunocerdan3
# RomiGameplays (Paper) vs Jeni (Paper) => Winner: Tie
# RomiGameplays (Lizard) vs Annie (Lizard) => Winner: Tie
# RomiGameplays (Scissors) vs SnoopiFredo (Lizard) => Winner: RomiGameplays
# Lukesize (Spock) vs brunocerdan3 (Scissors) => Winner: Lukesize
# Lukesize (Lizard) vs Jeni (Paper) => Winner: Lukesize
# Lukesize (Paper) vs Annie (Paper) => Winner: Tie
# Lukesize (Spock) vs SnoopiFredo (Scissors) => Winner: Lukesize
# brunocerdan3 (Spock) vs Jeni (Rock) => Winner: brunocerdan3
# brunocerdan3 (Lizard) vs Annie (Spock) => Winner: brunocerdan3
# brunocerdan3 (Scissors) vs SnoopiFredo (Paper) => Winner: brunocerdan3
# Jeni (Scissors) vs Annie (Scissors) => Winner: Tie
# Jeni (Scissors) vs SnoopiFredo (Scissors) => Winner: Tie
# Annie (Spock) vs SnoopiFredo (Paper) => Winner: SnoopiFredo
#
# Current Scores:
# Mword: 354 points
# Mari: 351 points
# CarlosGOD: 341 points
# Hisendo02: 330 points
# RomiGameplays: 337 points
# Lukesize: 365 points
# brunocerdan3: 355 points
# Jeni: 357 points
# Annie: 338 points
# SnoopiFredo: 349 points
#
#
# --- Round 97 ---
# Mword (Paper) vs Mari (Lizard) => Winner: Mari
# Mword (Lizard) vs CarlosGOD (Paper) => Winner: Mword
# Mword (Rock) vs Hisendo02 (Paper) => Winner: Hisendo02
# Mword (Paper) vs RomiGameplays (Spock) => Winner: Mword
# Mword (Paper) vs Lukesize (Paper) => Winner: Tie
# Mword (Rock) vs brunocerdan3 (Rock) => Winner: Tie
# Mword (Paper) vs Jeni (Paper) => Winner: Tie
# Mword (Spock) vs Annie (Scissors) => Winner: Mword
# Mword (Spock) vs SnoopiFredo (Lizard) => Winner: SnoopiFredo
# Mari (Rock) vs CarlosGOD (Rock) => Winner: Tie
# Mari (Lizard) vs Hisendo02 (Rock) => Winner: Hisendo02
# Mari (Paper) vs RomiGameplays (Spock) => Winner: Mari
# Mari (Spock) vs Lukesize (Scissors) => Winner: Mari
# Mari (Lizard) vs brunocerdan3 (Rock) => Winner: brunocerdan3
# Mari (Paper) vs Jeni (Paper) => Winner: Tie
# Mari (Spock) vs Annie (Spock) => Winner: Tie
# Mari (Spock) vs SnoopiFredo (Rock) => Winner: Mari
# CarlosGOD (Rock) vs Hisendo02 (Paper) => Winner: Hisendo02
# CarlosGOD (Lizard) vs RomiGameplays (Paper) => Winner: CarlosGOD
# CarlosGOD (Lizard) vs Lukesize (Rock) => Winner: Lukesize
# CarlosGOD (Lizard) vs brunocerdan3 (Lizard) => Winner: Tie
# CarlosGOD (Rock) vs Jeni (Rock) => Winner: Tie
# CarlosGOD (Scissors) vs Annie (Scissors) => Winner: Tie
# CarlosGOD (Scissors) vs SnoopiFredo (Scissors) => Winner: Tie
# Hisendo02 (Scissors) vs RomiGameplays (Spock) => Winner: RomiGameplays
# Hisendo02 (Rock) vs Lukesize (Spock) => Winner: Lukesize
# Hisendo02 (Spock) vs brunocerdan3 (Scissors) => Winner: Hisendo02
# Hisendo02 (Lizard) vs Jeni (Spock) => Winner: Hisendo02
# Hisendo02 (Paper) vs Annie (Lizard) => Winner: Annie
# Hisendo02 (Spock) vs SnoopiFredo (Rock) => Winner: Hisendo02
# RomiGameplays (Scissors) vs Lukesize (Paper) => Winner: RomiGameplays
# RomiGameplays (Lizard) vs brunocerdan3 (Spock) => Winner: RomiGameplays
# RomiGameplays (Scissors) vs Jeni (Scissors) => Winner: Tie
# RomiGameplays (Lizard) vs Annie (Scissors) => Winner: Annie
# RomiGameplays (Paper) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# Lukesize (Lizard) vs brunocerdan3 (Scissors) => Winner: brunocerdan3
# Lukesize (Scissors) vs Jeni (Paper) => Winner: Lukesize
# Lukesize (Paper) vs Annie (Paper) => Winner: Tie
# Lukesize (Lizard) vs SnoopiFredo (Paper) => Winner: Lukesize
# brunocerdan3 (Paper) vs Jeni (Lizard) => Winner: Jeni
# brunocerdan3 (Paper) vs Annie (Rock) => Winner: brunocerdan3
# brunocerdan3 (Paper) vs SnoopiFredo (Paper) => Winner: Tie
# Jeni (Paper) vs Annie (Scissors) => Winner: Annie
# Jeni (Spock) vs SnoopiFredo (Paper) => Winner: SnoopiFredo
# Annie (Paper) vs SnoopiFredo (Rock) => Winner: Annie
#
# Current Scores:
# Mword: 357 points
# Mari: 355 points
# CarlosGOD: 342 points
# Hisendo02: 336 points
# RomiGameplays: 340 points
# Lukesize: 369 points
# brunocerdan3: 358 points
# Jeni: 358 points
# Annie: 342 points
# SnoopiFredo: 352 points
#
#
# --- Round 98 ---
# Mword (Lizard) vs Mari (Paper) => Winner: Mword
# Mword (Spock) vs CarlosGOD (Scissors) => Winner: Mword
# Mword (Scissors) vs Hisendo02 (Scissors) => Winner: Tie
# Mword (Scissors) vs RomiGameplays (Scissors) => Winner: Tie
# Mword (Spock) vs Lukesize (Scissors) => Winner: Mword
# Mword (Spock) vs brunocerdan3 (Spock) => Winner: Tie
# Mword (Rock) vs Jeni (Paper) => Winner: Jeni
# Mword (Paper) vs Annie (Spock) => Winner: Mword
# Mword (Scissors) vs SnoopiFredo (Lizard) => Winner: Mword
# Mari (Scissors) vs CarlosGOD (Rock) => Winner: CarlosGOD
# Mari (Spock) vs Hisendo02 (Paper) => Winner: Hisendo02
# Mari (Paper) vs RomiGameplays (Rock) => Winner: Mari
# Mari (Lizard) vs Lukesize (Scissors) => Winner: Lukesize
# Mari (Rock) vs brunocerdan3 (Lizard) => Winner: Mari
# Mari (Lizard) vs Jeni (Scissors) => Winner: Jeni
# Mari (Lizard) vs Annie (Rock) => Winner: Annie
# Mari (Lizard) vs SnoopiFredo (Rock) => Winner: SnoopiFredo
# CarlosGOD (Paper) vs Hisendo02 (Spock) => Winner: CarlosGOD
# CarlosGOD (Lizard) vs RomiGameplays (Scissors) => Winner: RomiGameplays
# CarlosGOD (Scissors) vs Lukesize (Rock) => Winner: Lukesize
# CarlosGOD (Lizard) vs brunocerdan3 (Spock) => Winner: CarlosGOD
# CarlosGOD (Spock) vs Jeni (Lizard) => Winner: Jeni
# CarlosGOD (Paper) vs Annie (Paper) => Winner: Tie
# CarlosGOD (Lizard) vs SnoopiFredo (Paper) => Winner: CarlosGOD
# Hisendo02 (Spock) vs RomiGameplays (Scissors) => Winner: Hisendo02
# Hisendo02 (Rock) vs Lukesize (Scissors) => Winner: Hisendo02
# Hisendo02 (Scissors) vs brunocerdan3 (Paper) => Winner: Hisendo02
# Hisendo02 (Scissors) vs Jeni (Spock) => Winner: Jeni
# Hisendo02 (Scissors) vs Annie (Spock) => Winner: Annie
# Hisendo02 (Lizard) vs SnoopiFredo (Lizard) => Winner: Tie
# RomiGameplays (Lizard) vs Lukesize (Rock) => Winner: Lukesize
# RomiGameplays (Scissors) vs brunocerdan3 (Paper) => Winner: RomiGameplays
# RomiGameplays (Rock) vs Jeni (Rock) => Winner: Tie
# RomiGameplays (Lizard) vs Annie (Paper) => Winner: RomiGameplays
# RomiGameplays (Scissors) vs SnoopiFredo (Scissors) => Winner: Tie
# Lukesize (Paper) vs brunocerdan3 (Paper) => Winner: Tie
# Lukesize (Rock) vs Jeni (Rock) => Winner: Tie
# Lukesize (Lizard) vs Annie (Spock) => Winner: Lukesize
# Lukesize (Scissors) vs SnoopiFredo (Scissors) => Winner: Tie
# brunocerdan3 (Rock) vs Jeni (Lizard) => Winner: brunocerdan3
# brunocerdan3 (Paper) vs Annie (Lizard) => Winner: Annie
# brunocerdan3 (Scissors) vs SnoopiFredo (Scissors) => Winner: Tie
# Jeni (Paper) vs Annie (Lizard) => Winner: Annie
# Jeni (Lizard) vs SnoopiFredo (Paper) => Winner: Jeni
# Annie (Rock) vs SnoopiFredo (Scissors) => Winner: Annie
#
# Current Scores:
# Mword: 362 points
# Mari: 357 points
# CarlosGOD: 346 points
# Hisendo02: 340 points
# RomiGameplays: 343 points
# Lukesize: 373 points
# brunocerdan3: 359 points
# Jeni: 363 points
# Annie: 347 points
# SnoopiFredo: 353 points
#
#
# --- Round 99 ---
# Mword (Paper) vs Mari (Rock) => Winner: Mword
# Mword (Rock) vs CarlosGOD (Lizard) => Winner: Mword
# Mword (Spock) vs Hisendo02 (Scissors) => Winner: Mword
# Mword (Spock) vs RomiGameplays (Spock) => Winner: Tie
# Mword (Scissors) vs Lukesize (Lizard) => Winner: Mword
# Mword (Spock) vs brunocerdan3 (Lizard) => Winner: brunocerdan3
# Mword (Rock) vs Jeni (Lizard) => Winner: Mword
# Mword (Spock) vs Annie (Rock) => Winner: Mword
# Mword (Spock) vs SnoopiFredo (Scissors) => Winner: Mword
# Mari (Lizard) vs CarlosGOD (Lizard) => Winner: Tie
# Mari (Lizard) vs Hisendo02 (Paper) => Winner: Mari
# Mari (Lizard) vs RomiGameplays (Rock) => Winner: RomiGameplays
# Mari (Lizard) vs Lukesize (Spock) => Winner: Mari
# Mari (Paper) vs brunocerdan3 (Scissors) => Winner: brunocerdan3
# Mari (Paper) vs Jeni (Rock) => Winner: Mari
# Mari (Lizard) vs Annie (Spock) => Winner: Mari
# Mari (Lizard) vs SnoopiFredo (Lizard) => Winner: Tie
# CarlosGOD (Spock) vs Hisendo02 (Spock) => Winner: Tie
# CarlosGOD (Rock) vs RomiGameplays (Lizard) => Winner: CarlosGOD
# CarlosGOD (Scissors) vs Lukesize (Spock) => Winner: Lukesize
# CarlosGOD (Spock) vs brunocerdan3 (Lizard) => Winner: brunocerdan3
# CarlosGOD (Lizard) vs Jeni (Lizard) => Winner: Tie
# CarlosGOD (Paper) vs Annie (Lizard) => Winner: Annie
# CarlosGOD (Spock) vs SnoopiFredo (Lizard) => Winner: SnoopiFredo
# Hisendo02 (Spock) vs RomiGameplays (Lizard) => Winner: RomiGameplays
# Hisendo02 (Paper) vs Lukesize (Paper) => Winner: Tie
# Hisendo02 (Paper) vs brunocerdan3 (Paper) => Winner: Tie
# Hisendo02 (Scissors) vs Jeni (Rock) => Winner: Jeni
# Hisendo02 (Rock) vs Annie (Rock) => Winner: Tie
# Hisendo02 (Spock) vs SnoopiFredo (Scissors) => Winner: Hisendo02
# RomiGameplays (Paper) vs Lukesize (Lizard) => Winner: Lukesize
# RomiGameplays (Spock) vs brunocerdan3 (Lizard) => Winner: brunocerdan3
# RomiGameplays (Lizard) vs Jeni (Paper) => Winner: RomiGameplays
# RomiGameplays (Paper) vs Annie (Spock) => Winner: RomiGameplays
# RomiGameplays (Spock) vs SnoopiFredo (Scissors) => Winner: RomiGameplays
# Lukesize (Lizard) vs brunocerdan3 (Paper) => Winner: Lukesize
# Lukesize (Paper) vs Jeni (Paper) => Winner: Tie
# Lukesize (Scissors) vs Annie (Spock) => Winner: Annie
# Lukesize (Paper) vs SnoopiFredo (Paper) => Winner: Tie
# brunocerdan3 (Lizard) vs Jeni (Spock) => Winner: brunocerdan3
# brunocerdan3 (Lizard) vs Annie (Scissors) => Winner: Annie
# brunocerdan3 (Lizard) vs SnoopiFredo (Paper) => Winner: brunocerdan3
# Jeni (Scissors) vs Annie (Rock) => Winner: Annie
# Jeni (Scissors) vs SnoopiFredo (Scissors) => Winner: Tie
# Annie (Lizard) vs SnoopiFredo (Rock) => Winner: SnoopiFredo
#
# Current Scores:
# Mword: 369 points
# Mari: 361 points
# CarlosGOD: 347 points
# Hisendo02: 341 points
# RomiGameplays: 348 points
# Lukesize: 376 points
# brunocerdan3: 365 points
# Jeni: 364 points
# Annie: 351 points
# SnoopiFredo: 355 points
#
#
# --- Round 100 ---
# Mword (Spock) vs Mari (Spock) => Winner: Tie
# Mword (Paper) vs CarlosGOD (Lizard) => Winner: CarlosGOD
# Mword (Spock) vs Hisendo02 (Paper) => Winner: Hisendo02
# Mword (Rock) vs RomiGameplays (Scissors) => Winner: Mword
# Mword (Paper) vs Lukesize (Paper) => Winner: Tie
# Mword (Spock) vs brunocerdan3 (Spock) => Winner: Tie
# Mword (Rock) vs Jeni (Rock) => Winner: Tie
# Mword (Scissors) vs Annie (Paper) => Winner: Mword
# Mword (Scissors) vs SnoopiFredo (Lizard) => Winner: Mword
# Mari (Scissors) vs CarlosGOD (Rock) => Winner: CarlosGOD
# Mari (Rock) vs Hisendo02 (Spock) => Winner: Hisendo02
# Mari (Rock) vs RomiGameplays (Spock) => Winner: RomiGameplays
# Mari (Lizard) vs Lukesize (Scissors) => Winner: Lukesize
# Mari (Lizard) vs brunocerdan3 (Paper) => Winner: Mari
# Mari (Scissors) vs Jeni (Rock) => Winner: Jeni
# Mari (Lizard) vs Annie (Paper) => Winner: Mari
# Mari (Lizard) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# CarlosGOD (Scissors) vs Hisendo02 (Spock) => Winner: Hisendo02
# CarlosGOD (Paper) vs RomiGameplays (Paper) => Winner: Tie
# CarlosGOD (Lizard) vs Lukesize (Spock) => Winner: CarlosGOD
# CarlosGOD (Lizard) vs brunocerdan3 (Lizard) => Winner: Tie
# CarlosGOD (Rock) vs Jeni (Rock) => Winner: Tie
# CarlosGOD (Spock) vs Annie (Lizard) => Winner: Annie
# CarlosGOD (Rock) vs SnoopiFredo (Rock) => Winner: Tie
# Hisendo02 (Rock) vs RomiGameplays (Scissors) => Winner: Hisendo02
# Hisendo02 (Lizard) vs Lukesize (Spock) => Winner: Hisendo02
# Hisendo02 (Scissors) vs brunocerdan3 (Lizard) => Winner: Hisendo02
# Hisendo02 (Paper) vs Jeni (Spock) => Winner: Hisendo02
# Hisendo02 (Spock) vs Annie (Scissors) => Winner: Hisendo02
# Hisendo02 (Lizard) vs SnoopiFredo (Scissors) => Winner: SnoopiFredo
# RomiGameplays (Paper) vs Lukesize (Rock) => Winner: RomiGameplays
# RomiGameplays (Scissors) vs brunocerdan3 (Rock) => Winner: brunocerdan3
# RomiGameplays (Paper) vs Jeni (Spock) => Winner: RomiGameplays
# RomiGameplays (Paper) vs Annie (Scissors) => Winner: Annie
# RomiGameplays (Lizard) vs SnoopiFredo (Spock) => Winner: RomiGameplays
# Lukesize (Paper) vs brunocerdan3 (Spock) => Winner: Lukesize
# Lukesize (Spock) vs Jeni (Spock) => Winner: Tie
# Lukesize (Paper) vs Annie (Rock) => Winner: Lukesize
# Lukesize (Rock) vs SnoopiFredo (Rock) => Winner: Tie
# brunocerdan3 (Paper) vs Jeni (Scissors) => Winner: Jeni
# brunocerdan3 (Scissors) vs Annie (Paper) => Winner: brunocerdan3
# brunocerdan3 (Spock) vs SnoopiFredo (Paper) => Winner: SnoopiFredo
# Jeni (Paper) vs Annie (Spock) => Winner: Jeni
# Jeni (Scissors) vs SnoopiFredo (Paper) => Winner: Jeni
# Annie (Spock) vs SnoopiFredo (Paper) => Winner: SnoopiFredo
#
# Current Scores:
# Mword: 372 points
# Mari: 363 points
# CarlosGOD: 350 points
# Hisendo02: 349 points
# RomiGameplays: 352 points
# Lukesize: 379 points
# brunocerdan3: 367 points
# Jeni: 368 points
# Annie: 353 points
# SnoopiFredo: 359 points
#
#
# --- Final Results ---
#             name  score  strategy
# 0          Mword    372  Scissors
# 1           Mari    363    Lizard
# 2      CarlosGOD    350      Rock
# 3      Hisendo02    349    Lizard
# 4  RomiGameplays    352    Lizard
# 5       Lukesize    379      Rock
# 6   brunocerdan3    367     Spock
# 7           Jeni    368  Scissors
# 8          Annie    353     Spock
# 9    SnoopiFredo    359     Paper
# Winner(s):
#        name  score strategy
# 5  Lukesize    379     Rock

# %% [markdown]
# # Abstraction of agents
#
# Let's see some abstraction known 'OOP', which stands for Objetc-Oriented Programming.
#
# * This is the creation of an agent object and its methods:

# %%
class Player:    # object class

    def __init__(self,name,score=0): # create the object (self) for the class
        self.name=name               # with some variables
        self.score=score

    def increase_score(self,value):  # metho for object class
        self.score+=value

# %% [markdown]
# Once created, you can give origin to instances of the object:

# %%
Mary=Player("Mary")
John=Player("John")

# %% [markdown]
# Let's use some previous code:

# %%
John_strategy=choice(strategies)
Mary_strategy=choice(strategies)

John_PayOff,Mary_PayOff=payoff[John_strategy,Mary_strategy]
John_PayOff,Mary_PayOff
# Out:
# (1, 0)

# %% [markdown]
# We use those values to change the instaces' variables, as defined in the object class:

# %%
John.increase_score(John_PayOff)
Mary.increase_score(Mary_PayOff)

# %% [markdown]
# The instances did update the score:

# %%
John.score, Mary.score
# Out:
# (1, 0)

# %% [markdown]
# * A new class that inherists previous class:

# %%
class PlayerBetter(Player):
    def __init__(self,name,score=0):
        Player.__init__(self,name,score=0)
        self.strategy=None

    def increase_score(self,value):
        self.score+=value

    def get_strategy(self):
        from random import choice
        strategies=['Rock','Paper','Scissors']
        self.strategy=choice(strategies)
        return self.strategy

# %% [markdown]
# We can use the new class:

# %%
Mary=PlayerBetter("Mary")
John=PlayerBetter("John")

# not needed
# John_strategy=choice(strategies)
# Mary_strategy=choice(strategies)

John_PayOff,Mary_PayOff=payoff[John.get_strategy(),Mary.get_strategy()]
John.increase_score(John_PayOff)
Mary.increase_score(Mary_PayOff)
##
John.score, Mary.score
# Out:
# (1, 0)

# %% [markdown]
# The new class saves the current strategy:

# %%
print(John.strategy, Mary.strategy)
# Out:
# Paper Rock

# %% [markdown]
# We can use the new class repeatedly:

# %%
Mary=PlayerBetter("Mary")
John=PlayerBetter("John")

for i in range(10):
    John_PayOff,Mary_PayOff=payoff[John.get_strategy(),Mary.get_strategy()]
    John.increase_score(John_PayOff)
    Mary.increase_score(Mary_PayOff)
    # see current result
    print('round:',i+1)
    print(John.score, Mary.score)
    print(John.strategy, Mary.strategy)
# Out:
# round: 1
# 0 0
# Scissors Scissors
# round: 2
# 0 1
# Paper Scissors
# round: 3
# 0 1
# Paper Paper
# round: 4
# 0 2
# Paper Scissors
# round: 5
# 1 2
# Rock Scissors
# round: 6
# 1 3
# Rock Paper
# round: 7
# 2 3
# Rock Scissors
# round: 8
# 2 4
# Rock Paper
# round: 9
# 3 4
# Scissors Paper
# round: 10
# 4 4
# Paper Rock

# %% [markdown]
# <div class="alert alert-danger">
#   <strong>CHALLENGE!</strong>
#    <br> * Create classes that allows you to have several players play 100 rounds.
#    <br> * Save the scores.
#    <br> * Declare a winner
# </div>
